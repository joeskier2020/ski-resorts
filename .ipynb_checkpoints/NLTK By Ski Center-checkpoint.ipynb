# %%
# NLP Processing
# In this script we will process the text reviews for the ski centers.  Here we will
# organize the corpus to be grouped by the ski centers.  There are a total of 289 
# ski centers.  So there will 289 documents.  All the reviews for a given ski center
# will be grouped to that ski center.

# The text will be pre-processed to lower case, remove stop words, remove any numbers
# and remove punctuation and lemmatize.

# The most frenquently words for each ski center will be determined.

# And TFIDF will be used to remove the 'stop words' common to these corpus.  And there 
# will be more relevant frequently used reviews.

import pandas as pd

#  Read in the data set with the text reviews 
reviews = pd.read_csv ('OnTheSnow_SkiAreaReviews.csv')

#  Give the data set friendly column names 
reviews.columns = ['placeholder','state','ski_area','reviewer_name','review_date',
                        'review_stars','review_text']

# %%
#  Here we calculate the average number of stars.  And find the ski centers with the
#  most number of stars.

#  aggregate the ski centers by average number of stars for their reviews 
#  and count the number of reviews per ski center
ski_areas_stars = reviews.groupby(['ski_area']).agg({'review_stars':['mean','count']})
ski_areas_stars = ski_areas_stars.sort_values(by=[('review_stars',  'mean')],ascending=False)

#  round the average number of stars to one decimal point
ski_areas_stars[('review_stars',  'mean')] = ski_areas_stars[('review_stars',  'mean')].round(1)

#  Print out a table with the best ski center ratings
print("\nHere are the ski centers with the top ratings:")
print("(Also provided is the number of reveiws.)\n")
print(ski_areas_stars.head(10))


#  This code creates a histogram of the number of stars for the reviews
alt = ski_areas_stars[('review_stars',  'mean')].hist(bins=10)
alt.set_xlabel("Average Number of Stars Per Ski Area", labelpad=20, weight='bold', size=12)
alt.set_ylabel("Number of Ski Areas", labelpad=20, weight='bold', size=12)
alt.set_title("Histogram of Number of Stars Given in the Reviews")

#  Create a list of the ski centers ordered by best ratings.
#  This list will be used later on to group the corpus by ski center
ski_areas = ski_areas_stars
# Out:
# Here are the ski centers with the top ratings:
# (Also provided is the number of reveiws.)
#
#                               review_stars
#                                       mean count
# ski_area
# blacktail-mountain-ski-area            4.8    24
# blackjack-ski-resort                   4.8    26
# mad-river-glen                         4.8    34
# ski-brule                              4.8  1315
# magic-mountain                         4.8    38
# christie-mountain                      4.8    21
# wildcat-mountain                       4.7    37
# norway-mountain                        4.7    24
# royal-mountain-ski-area                4.7    16
# anthony-lakes-mountain-resort          4.7    22

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np



# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# function to pre-process the reviews.  I.E. remove numbers and punctions, tokenize into words and lemmatize
def get_clean_review(df):
    clean_review = []
    for index, row in df.iterrows():
        review_str = str(row['review_text'])
        # split the string into a list of words
        tokens = word_tokenize(review_str)
        lower_tokens = [t.lower() for t in tokens]

        # removes anything not alpha characters such as punctuation and numbers
        alpha_only = [t for t in lower_tokens if t.isalpha()]

        # removes the stop words from the text
        no_stops = [t for t in alpha_only if t not in stopwords.words('english')]

        # Lemmatize all tokens into a new list: lemmatized
        lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]

        # make a list of lists
        for w in lemmatized:
            clean_review.append(w)
        
    return clean_review

reviews_ski_area = []

# loop through the ski areas to create 291 documents.  One document for each ski center.  The 
# document consists of a list of cleaned words
count = 1
total_count = len(ski_areas)
for sa in ski_areas.index:
    reviews_to_pass= reviews[reviews['ski_area']==sa]
    print("Processing",count,"of",total_count,":",sa, "there are",len(reviews_to_pass),"reviews to process")
    count += 1
    reviews_ski_area.append( get_clean_review(reviews_to_pass))
# Out:
# Processing 1 of 291 : blacktail-mountain-ski-area there are 24 reviews to process
# Processing 2 of 291 : blackjack-ski-resort there are 26 reviews to process
# Processing 3 of 291 : mad-river-glen there are 34 reviews to process
# Processing 4 of 291 : ski-brule there are 1315 reviews to process
# Processing 5 of 291 : magic-mountain there are 38 reviews to process
# Processing 6 of 291 : christie-mountain there are 21 reviews to process
# Processing 7 of 291 : wildcat-mountain there are 37 reviews to process
# Processing 8 of 291 : norway-mountain there are 24 reviews to process
# Processing 9 of 291 : royal-mountain-ski-area there are 16 reviews to process
# Processing 10 of 291 : anthony-lakes-mountain-resort there are 22 reviews to process
# Processing 11 of 291 : holimont-ski-area there are 18 reviews to process
# Processing 12 of 291 : brundage-mountain-resort there are 33 reviews to process
# Processing 13 of 291 : mccauley-mountain-ski-center there are 20 reviews to process
# Processing 14 of 291 : beaver-mountain there are 25 reviews to process
# Processing 15 of 291 : eaglecrest-ski-area there are 19 reviews to process
# Processing 16 of 291 : lost-trail-powder-mtn there are 31 reviews to process
# Processing 17 of 291 : snow-ridge there are 15 reviews to process
# Processing 18 of 291 : big-powderhorn-mountain there are 60 reviews to process
# Processing 19 of 291 : discovery-ski-area there are 32 reviews to process
# Processing 20 of 291 : showdown-ski-area there are 17 reviews to process
# Processing 21 of 291 : telluride there are 114 reviews to process
# Processing 22 of 291 : bruce-mound there are 14 reviews to process
# Processing 23 of 291 : mission-ridge there are 42 reviews to process
# Processing 24 of 291 : sugar-bowl-resort there are 48 reviews to process
# Processing 25 of 291 : pebble-creek-ski-area there are 34 reviews to process
# Processing 26 of 291 : plattekill-mountain there are 38 reviews to process
# Processing 27 of 291 : grand-targhee-resort there are 64 reviews to process
# Processing 28 of 291 : hoodoo-ski-area there are 33 reviews to process
# Processing 29 of 291 : taos-ski-valley there are 138 reviews to process
# Processing 30 of 291 : white-pass there are 57 reviews to process
# Processing 31 of 291 : mount-bohemia there are 50 reviews to process
# Processing 32 of 291 : wolf-creek-ski-area there are 155 reviews to process
# Processing 33 of 291 : soldier-mountain-ski-area there are 18 reviews to process
# Processing 34 of 291 : powderhorn there are 35 reviews to process
# Processing 35 of 291 : trollhaugen there are 23 reviews to process
# Processing 36 of 291 : crested-butte-mountain-resort there are 89 reviews to process
# Processing 37 of 291 : king-pine there are 17 reviews to process
# Processing 38 of 291 : snowbird there are 134 reviews to process
# Processing 39 of 291 : titus-mountain there are 26 reviews to process
# Processing 40 of 291 : alta-ski-area there are 140 reviews to process
# Processing 41 of 291 : nubs-nob-ski-area there are 55 reviews to process
# Processing 42 of 291 : powder-mountain there are 88 reviews to process
# Processing 43 of 291 : peekn-peak there are 62 reviews to process
# Processing 44 of 291 : aspen-snowmass there are 62 reviews to process
# Processing 45 of 291 : mt-rose-ski-tahoe there are 49 reviews to process
# Processing 46 of 291 : indianhead-mountain there are 115 reviews to process
# Processing 47 of 291 : badger-pass there are 25 reviews to process
# Processing 48 of 291 : sugarloaf there are 54 reviews to process
# Processing 49 of 291 : bridger-bowl there are 43 reviews to process
# Processing 50 of 291 : arapahoe-basin-ski-area there are 138 reviews to process
# Processing 51 of 291 : donner-ski-ranch there are 82 reviews to process
# Processing 52 of 291 : chestnut-mountain-resort there are 41 reviews to process
# Processing 53 of 291 : ski-granby-ranch there are 38 reviews to process
# Processing 54 of 291 : kirkwood there are 107 reviews to process
# Processing 55 of 291 : june-mountain there are 33 reviews to process
# Processing 56 of 291 : mt-abram-ski-resort there are 22 reviews to process
# Processing 57 of 291 : loveland there are 107 reviews to process
# Processing 58 of 291 : big-sky-resort there are 136 reviews to process
# Processing 59 of 291 : ski-snowstar-winter-sports-park there are 21 reviews to process
# Processing 60 of 291 : mount-ashland there are 25 reviews to process
# Processing 61 of 291 : big-squaw-mountain-ski-resort there are 13 reviews to process
# Processing 62 of 291 : jackson-hole there are 103 reviews to process
# Processing 63 of 291 : snowbasin there are 94 reviews to process
# Processing 64 of 291 : deer-valley-resort there are 100 reviews to process
# Processing 65 of 291 : shanty-creek there are 63 reviews to process
# Processing 66 of 291 : tahoe-donner there are 52 reviews to process
# Processing 67 of 291 : monarch-mountain there are 71 reviews to process
# Processing 68 of 291 : cannon-mountain there are 60 reviews to process
# Processing 69 of 291 : elk-mountain-ski-resort there are 108 reviews to process
# Processing 70 of 291 : loon-mountain there are 86 reviews to process
# Processing 71 of 291 : mt-baker there are 92 reviews to process
# Processing 72 of 291 : holiday-valley there are 73 reviews to process
# Processing 73 of 291 : pine-mountain there are 56 reviews to process
# Processing 74 of 291 : coffee-mill-ski-snowboard-resort there are 13 reviews to process
# Processing 75 of 291 : beaver-creek there are 106 reviews to process
# Processing 76 of 291 : gore-mountain there are 86 reviews to process
# Processing 77 of 291 : pine-knob-ski-resort there are 15 reviews to process
# Processing 78 of 291 : sugarbush there are 90 reviews to process
# Processing 79 of 291 : mohawk-mountain there are 46 reviews to process
# Processing 80 of 291 : black-mountain there are 21 reviews to process
# Processing 81 of 291 : mount-holly there are 32 reviews to process
# Processing 82 of 291 : sierra-at-tahoe there are 59 reviews to process
# Processing 83 of 291 : jay-peak there are 133 reviews to process
# Processing 84 of 291 : copper-mountain-resort there are 138 reviews to process
# Processing 85 of 291 : sunlight-mountain-resort there are 35 reviews to process
# Processing 86 of 291 : snowy-range-ski-recreation-area there are 41 reviews to process
# Processing 87 of 291 : pomerelle-mountain-resort there are 36 reviews to process
# Processing 88 of 291 : cranmore-mountain-resort there are 31 reviews to process
# Processing 89 of 291 : steamboat there are 150 reviews to process
# Processing 90 of 291 : crystal-mountain there are 44 reviews to process
# Processing 91 of 291 : lookout-pass-ski-area there are 70 reviews to process
# Processing 92 of 291 : ski-cooper there are 32 reviews to process
# Processing 93 of 291 : diamond-peak there are 32 reviews to process
# Processing 94 of 291 : pajarito-mountain-ski-area there are 34 reviews to process
# Processing 95 of 291 : ski-sawmill there are 21 reviews to process
# Processing 96 of 291 : snow-trails there are 29 reviews to process
# Processing 97 of 291 : canaan-valley-resort there are 37 reviews to process
# Processing 98 of 291 : whitefish-mountain-resort there are 82 reviews to process
# Processing 99 of 291 : terry-peak-ski-area there are 25 reviews to process
# Processing 100 of 291 : eagle-point there are 25 reviews to process
# Processing 101 of 291 : blue-knob there are 51 reviews to process
# Processing 102 of 291 : whiteface-mountain-resort there are 81 reviews to process
# Processing 103 of 291 : brighton-resort there are 73 reviews to process
# Processing 104 of 291 : crotched-mountain there are 46 reviews to process
# Processing 105 of 291 : silverton-mountain there are 59 reviews to process
# Processing 106 of 291 : park-city-mountain-resort there are 135 reviews to process
# Processing 107 of 291 : mammoth-mountain-ski-area there are 142 reviews to process
# Processing 108 of 291 : otis-ridge-ski-area there are 13 reviews to process
# Processing 109 of 291 : breckenridge there are 188 reviews to process
# Processing 110 of 291 : mt-hood-ski-bowl there are 42 reviews to process
# Processing 111 of 291 : boyne-highlands there are 45 reviews to process
# Processing 112 of 291 : great-divide there are 31 reviews to process
# Processing 113 of 291 : vail there are 203 reviews to process
# Processing 114 of 291 : suicide-six there are 18 reviews to process
# Processing 115 of 291 : hogadon there are 19 reviews to process
# Processing 116 of 291 : bear-valley there are 57 reviews to process
# Processing 117 of 291 : montana-snowbowl there are 29 reviews to process
# Processing 118 of 291 : sundance there are 37 reviews to process
# Processing 119 of 291 : red-river there are 88 reviews to process
# Processing 120 of 291 : keystone there are 141 reviews to process
# Processing 121 of 291 : mount-southington-ski-area there are 38 reviews to process
# Processing 122 of 291 : mount-kato-ski-area there are 15 reviews to process
# Processing 123 of 291 : woods-valley-ski-area there are 16 reviews to process
# Processing 124 of 291 : crystal-mountain-wa there are 98 reviews to process
# Processing 125 of 291 : brian-head-resort there are 70 reviews to process
# Processing 126 of 291 : blue-hills-ski-area there are 16 reviews to process
# Processing 127 of 291 : winter-park-resort there are 191 reviews to process
# Processing 128 of 291 : lutsen-mountains there are 85 reviews to process
# Processing 129 of 291 : devils-head there are 95 reviews to process
# Processing 130 of 291 : perfect-north-slopes there are 69 reviews to process
# Processing 131 of 291 : sun-valley there are 65 reviews to process
# Processing 132 of 291 : cascade-mountain there are 64 reviews to process
# Processing 133 of 291 : sundown-mountain there are 29 reviews to process
# Processing 134 of 291 : bretton-woods there are 82 reviews to process
# Processing 135 of 291 : schweitzer there are 71 reviews to process
# Processing 136 of 291 : dodge-ridge there are 68 reviews to process
# Processing 137 of 291 : spirit-mountain there are 40 reviews to process
# Processing 138 of 291 : sunday-river there are 94 reviews to process
# Processing 139 of 291 : solitude-mountain-resort there are 82 reviews to process
# Processing 140 of 291 : snow-king-resort there are 15 reviews to process
# Processing 141 of 291 : bogus-basin there are 58 reviews to process
# Processing 142 of 291 : tamarack-resort there are 55 reviews to process
# Processing 143 of 291 : brandywine there are 39 reviews to process
# Processing 144 of 291 : appalachian-ski-mtn there are 48 reviews to process
# Processing 145 of 291 : stowe-mountain-resort there are 106 reviews to process
# Processing 146 of 291 : jiminy-peak there are 80 reviews to process
# Processing 147 of 291 : boston-mills there are 45 reviews to process
# Processing 148 of 291 : belleayre there are 89 reviews to process
# Processing 149 of 291 : alpental there are 54 reviews to process
# Processing 150 of 291 : timberline-lodge there are 42 reviews to process
# Processing 151 of 291 : snow-valley there are 61 reviews to process
# Processing 152 of 291 : catamount-ski-ride-area there are 60 reviews to process
# Processing 153 of 291 : bear-creek-mountain-resort there are 69 reviews to process
# Processing 154 of 291 : caberfae-peaks-ski-golf-resort there are 56 reviews to process
# Processing 155 of 291 : dry-hill-ski-area there are 18 reviews to process
# Processing 156 of 291 : bromley-mountain there are 36 reviews to process
# Processing 157 of 291 : whitecap-mountain there are 54 reviews to process
# Processing 158 of 291 : red-lodge-mountain there are 43 reviews to process
# Processing 159 of 291 : kelly-canyon-ski-area there are 17 reviews to process
# Processing 160 of 291 : giants-ridge-resort there are 17 reviews to process
# Processing 161 of 291 : sno-mountain there are 134 reviews to process
# Processing 162 of 291 : bryce-resort there are 31 reviews to process
# Processing 163 of 291 : mount-holiday-ski-area there are 14 reviews to process
# Processing 164 of 291 : mount-peter-ski-area there are 55 reviews to process
# Processing 165 of 291 : blandford-ski-area there are 19 reviews to process
# Processing 166 of 291 : eagle-rock there are 19 reviews to process
# Processing 167 of 291 : smugglers-notch-resort there are 82 reviews to process
# Processing 168 of 291 : killington-resort there are 204 reviews to process
# Processing 169 of 291 : alyeska-resort there are 43 reviews to process
# Processing 170 of 291 : waterville-valley there are 54 reviews to process
# Processing 171 of 291 : pico-mountain-at-killington there are 39 reviews to process
# Processing 172 of 291 : bittersweet-ski-area there are 49 reviews to process
# Processing 173 of 291 : nordic-mountain there are 27 reviews to process
# Processing 174 of 291 : durango-mountain-resort there are 97 reviews to process
# Processing 175 of 291 : okemo-mountain-resort there are 132 reviews to process
# Processing 176 of 291 : willamette-pass there are 52 reviews to process
# Processing 177 of 291 : mad-river-mountain there are 72 reviews to process
# Processing 178 of 291 : stratton-mountain there are 111 reviews to process
# Processing 179 of 291 : song-mountain there are 15 reviews to process
# Processing 180 of 291 : berkshire-east there are 35 reviews to process
# Processing 181 of 291 : tyrol-basin there are 35 reviews to process
# Processing 182 of 291 : ski-sundown there are 39 reviews to process
# Processing 183 of 291 : bear-mountain there are 52 reviews to process
# Processing 184 of 291 : attitash there are 55 reviews to process
# Processing 185 of 291 : pats-peak there are 50 reviews to process
# Processing 186 of 291 : wolf-creek there are 18 reviews to process
# Processing 187 of 291 : angel-fire-resort there are 111 reviews to process
# Processing 188 of 291 : wild-mountain-ski-snowboard-area there are 31 reviews to process
# Processing 189 of 291 : snow-summit there are 60 reviews to process
# Processing 190 of 291 : sipapu-ski-and-summer-resort there are 57 reviews to process
# Processing 191 of 291 : ski-butternut there are 64 reviews to process
# Processing 192 of 291 : andes-tower-hills-ski-area there are 20 reviews to process
# Processing 193 of 291 : bousquet-ski-area there are 16 reviews to process
# Processing 194 of 291 : boyne-mountain-resort there are 50 reviews to process
# Processing 195 of 291 : ski-china-peak there are 64 reviews to process
# Processing 196 of 291 : granite-peak-ski-area there are 111 reviews to process
# Processing 197 of 291 : burke-mountain there are 33 reviews to process
# Processing 198 of 291 : squaw-valley-usa there are 113 reviews to process
# Processing 199 of 291 : paoli-peaks there are 40 reviews to process
# Processing 200 of 291 : mount-shasta-board-ski-park there are 32 reviews to process
# Processing 201 of 291 : bristol-mountain there are 59 reviews to process
# Processing 202 of 291 : swain there are 20 reviews to process
# Processing 203 of 291 : shawnee-peak there are 30 reviews to process
# Processing 204 of 291 : snowshoe-mountain-resort there are 146 reviews to process
# Processing 205 of 291 : jack-frost there are 53 reviews to process
# Processing 206 of 291 : powder-ridge-ski-area there are 13 reviews to process
# Processing 207 of 291 : mt-baldy there are 77 reviews to process
# Processing 208 of 291 : windham-mountain there are 61 reviews to process
# Processing 209 of 291 : wisp there are 74 reviews to process
# Processing 210 of 291 : bluewood there are 26 reviews to process
# Processing 211 of 291 : alpine-valley-resort there are 74 reviews to process
# Processing 212 of 291 : new-hermon-mountain there are 14 reviews to process
# Processing 213 of 291 : blue-mountain-ski-area there are 189 reviews to process
# Processing 214 of 291 : timber-ridge there are 30 reviews to process
# Processing 215 of 291 : massanutten there are 46 reviews to process
# Processing 216 of 291 : ski-santa-fe there are 100 reviews to process
# Processing 217 of 291 : silver-mountain there are 80 reviews to process
# Processing 218 of 291 : tussey-mountain there are 20 reviews to process
# Processing 219 of 291 : wintergreen-resort there are 69 reviews to process
# Processing 220 of 291 : sunburst there are 32 reviews to process
# Processing 221 of 291 : roundtop-mountain-resort there are 55 reviews to process
# Processing 222 of 291 : big-boulder there are 43 reviews to process
# Processing 223 of 291 : bolton-valley there are 47 reviews to process
# Processing 224 of 291 : heavenly-mountain-resort there are 157 reviews to process
# Processing 225 of 291 : northstar-california there are 102 reviews to process
# Processing 226 of 291 : cataloochee-ski-area there are 76 reviews to process
# Processing 227 of 291 : mount-sunapee there are 75 reviews to process
# Processing 228 of 291 : mt-hood-meadows there are 101 reviews to process
# Processing 229 of 291 : brantling-ski-slopes there are 21 reviews to process
# Processing 230 of 291 : mount-snow there are 135 reviews to process
# Processing 231 of 291 : greek-peak there are 57 reviews to process
# Processing 232 of 291 : willard-mountain there are 14 reviews to process
# Processing 233 of 291 : buck-hill there are 34 reviews to process
# Processing 234 of 291 : sunrise-park-resort there are 121 reviews to process
# Processing 235 of 291 : gunstock there are 41 reviews to process
# Processing 236 of 291 : labrador-mt there are 21 reviews to process
# Processing 237 of 291 : ski-beech-mountain-resort there are 82 reviews to process
# Processing 238 of 291 : mt-bachelor there are 101 reviews to process
# Processing 239 of 291 : welch-village there are 39 reviews to process
# Processing 240 of 291 : marquette-mountain there are 26 reviews to process
# Processing 241 of 291 : afton-alps there are 49 reviews to process
# Processing 242 of 291 : christmas-mountain there are 25 reviews to process
# Processing 243 of 291 : ragged-mountain-resort there are 59 reviews to process
# Processing 244 of 291 : magic-mountain-ski-area there are 20 reviews to process
# Processing 245 of 291 : whitetail-resort there are 68 reviews to process
# Processing 246 of 291 : shawnee-mountain-ski-area there are 45 reviews to process
# Processing 247 of 291 : ski-mystic-at-deer-mountain there are 16 reviews to process
# Processing 248 of 291 : swiss-valley there are 27 reviews to process
# Processing 249 of 291 : toggenburg-mountain there are 19 reviews to process
# Processing 250 of 291 : eldora-mountain-resort there are 84 reviews to process
# Processing 251 of 291 : west-mountain there are 35 reviews to process
# Processing 252 of 291 : wachusett-mountain-ski-area there are 81 reviews to process
# Processing 253 of 291 : boreal there are 48 reviews to process
# Processing 254 of 291 : alpine-valley there are 28 reviews to process
# Processing 255 of 291 : wilmot-mountain there are 55 reviews to process
# Processing 256 of 291 : arizona-snowbowl there are 107 reviews to process
# Processing 257 of 291 : stevens-pass-resort there are 102 reviews to process
# Processing 258 of 291 : wolf-ridge-ski-resort there are 36 reviews to process
# Processing 259 of 291 : grand-geneva there are 21 reviews to process
# Processing 260 of 291 : kissing-bridge there are 27 reviews to process
# Processing 261 of 291 : hidden-valley-ski-area there are 33 reviews to process
# Processing 262 of 291 : timberline-four-seasons there are 62 reviews to process
# Processing 263 of 291 : hunter-mountain there are 113 reviews to process
# Processing 264 of 291 : liberty there are 68 reviews to process
# Processing 265 of 291 : cooper-spur there are 18 reviews to process
# Processing 266 of 291 : 49-degrees-north there are 60 reviews to process
# Processing 267 of 291 : mountain-high there are 80 reviews to process
# Processing 268 of 291 : snow-creek there are 30 reviews to process
# Processing 269 of 291 : soda-springs there are 25 reviews to process
# Processing 270 of 291 : cannonsburg there are 68 reviews to process
# Processing 271 of 291 : the-summit-at-snoqualmie there are 53 reviews to process
# Processing 272 of 291 : bradford-ski-area there are 14 reviews to process
# Processing 273 of 291 : spring-mountain-ski-area there are 63 reviews to process
# Processing 274 of 291 : camelback-mountain-resort there are 146 reviews to process
# Processing 275 of 291 : big-bear there are 35 reviews to process
# Processing 276 of 291 : winterplace-ski-resort there are 58 reviews to process
# Processing 277 of 291 : mount-la-crosse there are 23 reviews to process
# Processing 278 of 291 : villa-olivia there are 31 reviews to process
# Processing 279 of 291 : ski-apache there are 172 reviews to process
# Processing 280 of 291 : las-vegas-ski-and-snowboard-resort there are 54 reviews to process
# Processing 281 of 291 : hyland-ski-snowboard-area there are 27 reviews to process
# Processing 282 of 291 : woodbury-ski-area there are 22 reviews to process
# Processing 283 of 291 : sandia-peak there are 33 reviews to process
# Processing 284 of 291 : sugar-mountain-resort there are 129 reviews to process
# Processing 285 of 291 : ober-gatlinburg-ski-resort there are 46 reviews to process
# Processing 286 of 291 : mountain-creek-resort there are 148 reviews to process
# Processing 287 of 291 : mount-brighton there are 37 reviews to process
# Processing 288 of 291 : campgaw-mountain there are 32 reviews to process
# Processing 289 of 291 : whaleback-mountain there are 12 reviews to process
# Processing 290 of 291 : mt-crescent-ski-area there are 28 reviews to process
# Processing 291 of 291 : holiday-mountain there are 13 reviews to process

# %%
from gensim.corpora.dictionary import Dictionary

# Create a Dictionary from the articles: dictionary
dictionary_ski_area = Dictionary(reviews_ski_area)

# Create a MmCorpus: corpus
corpus_ski_areas = [dictionary_ski_area.doc2bow(r) for r in reviews_ski_area]

# %%
#  Here we organize the words into most frequently used words by ski center.
#  The weights of the words are just number of times that they appeared.

from collections import defaultdict
import itertools

count =0 

for doc in  corpus_ski_areas:
    print("\nHere are the frequent words from",ski_areas.index[count],"\n")
    count +=1
    # Sort the doc for frequency: bow_doc
    bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)

    # Print the top 5 words of the document alongside the count
    for word_id, word_count in bow_doc[:5]:
        print(dictionary_ski_area.get(word_id), word_count)

    # Create the defaultdict: total_word_count
    total_word_count = defaultdict(int)
    for word_id, word_count in itertools.chain.from_iterable(corpus_ski_areas):
        total_word_count[word_id] += word_count
    

#  These are the frequent words from each ski center.  It is clear that the name 
#  of the ski center is usually one of the most frequent words.  It is also clear
#  that there are stop words that are common to this corpus.  These words will be 
#  given less weight in the next step (TFIDF analysis)
# Out:
# Here are the frequent words from blacktail-mountain-ski-area
#
# great 31
# mountain 20
# blacktail 17
# resort 15
# ski 15
#
# Here are the frequent words from blackjack-ski-resort
#
# great 31
# blackjack 26
# ski 20
# hill 17
# time 17
#
# Here are the frequent words from mad-river-glen
#
# ski 37
# skiing 31
# one 28
# snow 27
# trail 27
#
# Here are the frequent words from ski-brule
#
# great 820
# ski 757
# brule 524
# family 442
# friendly 390
#
# Here are the frequent words from magic-mountain
#
# magic 65
# mountain 56
# ski 34
# great 29
# place 25
#
# Here are the frequent words from christie-mountain
#
# great 29
# park 19
# run 18
# ski 18
# terrain 17
#
# Here are the frequent words from wildcat-mountain
#
# mountain 49
# wildcat 41
# trail 34
# great 28
# ski 28
#
# Here are the frequent words from norway-mountain
#
# great 31
# hill 31
# place 19
# ski 19
# kid 16
#
# Here are the frequent words from royal-mountain-ski-area
#
# mountain 21
# great 10
# family 9
# place 7
# fun 6
#
# Here are the frequent words from anthony-lakes-mountain-resort
#
# resort 16
# good 15
# lift 15
# run 15
# great 14
#
# Here are the frequent words from holimont-ski-area
#
# holimont 16
# good 14
# ski 14
# skiing 14
# great 12
#
# Here are the frequent words from brundage-mountain-resort
#
# great 36
# mountain 23
# snow 22
# brundage 20
# resort 18
#
# Here are the frequent words from mccauley-mountain-ski-center
#
# great 24
# run 22
# mountain 19
# ski 18
# mccauley 15
#
# Here are the frequent words from beaver-mountain
#
# mountain 28
# resort 24
# great 22
# skiing 21
# beav 16
#
# Here are the frequent words from eaglecrest-ski-area
#
# eaglecrest 22
# terrain 21
# lift 20
# area 19
# mountain 19
#
# Here are the frequent words from lost-trail-powder-mtn
#
# trail 28
# lost 25
# ski 25
# great 17
# lift 15
#
# Here are the frequent words from snow-ridge
#
# snow 32
# great 25
# hill 20
# ridge 18
# trail 16
#
# Here are the frequent words from big-powderhorn-mountain
#
# powderhorn 63
# great 58
# skiing 58
# ski 57
# run 56
#
# Here are the frequent words from discovery-ski-area
#
# ski 37
# discovery 30
# run 28
# great 26
# terrain 24
#
# Here are the frequent words from showdown-ski-area
#
# ski 17
# great 15
# snow 13
# good 9
# run 9
#
# Here are the frequent words from telluride
#
# telluride 161
# mountain 111
# ski 110
# town 92
# great 83
#
# Here are the frequent words from bruce-mound
#
# hill 12
# skiing 12
# ski 11
# great 10
# run 9
#
# Here are the frequent words from mission-ridge
#
# mission 56
# snow 36
# ridge 35
# great 34
# mountain 33
#
# Here are the frequent words from sugar-bowl-resort
#
# sugar 36
# bowl 35
# resort 33
# lift 30
# ski 26
#
# Here are the frequent words from pebble-creek-ski-area
#
# pebble 36
# ski 32
# great 22
# place 21
# mountain 15
#
# Here are the frequent words from plattekill-mountain
#
# ski 55
# mountain 41
# great 36
# place 30
# trail 26
#
# Here are the frequent words from grand-targhee-resort
#
# targhee 71
# snow 70
# day 58
# great 52
# resort 50
#
# Here are the frequent words from hoodoo-ski-area
#
# great 34
# ski 34
# hoodoo 27
# resort 22
# skiing 18
#
# Here are the frequent words from taos-ski-valley
#
# tao 265
# ski 214
# mountain 117
# great 110
# snow 98
#
# Here are the frequent words from white-pass
#
# pas 55
# white 53
# ski 38
# great 35
# resort 29
#
# Here are the frequent words from mount-bohemia
#
# place 50
# bohemia 48
# run 47
# day 43
# snow 42
#
# Here are the frequent words from wolf-creek-ski-area
#
# wolf 206
# creek 193
# snow 167
# ski 130
# lift 128
#
# Here are the frequent words from soldier-mountain-ski-area
#
# mountain 22
# soldier 16
# great 12
# day 11
# ski 10
#
# Here are the frequent words from powderhorn
#
# powderhorn 24
# great 20
# lift 18
# mountain 18
# ski 17
#
# Here are the frequent words from trollhaugen
#
# trollhaugen 30
# ski 19
# day 17
# place 15
# park 14
#
# Here are the frequent words from crested-butte-mountain-resort
#
# ski 92
# town 90
# butte 82
# mountain 81
# great 79
#
# Here are the frequent words from king-pine
#
# great 15
# mountain 15
# time 14
# lift 11
# pine 11
#
# Here are the frequent words from snowbird
#
# snowbird 170
# day 106
# snow 100
# ski 92
# resort 82
#
# Here are the frequent words from titus-mountain
#
# mountain 21
# great 20
# titus 20
# beginner 12
# trail 12
#
# Here are the frequent words from alta-ski-area
#
# alta 298
# ski 144
# day 134
# snow 114
# skiing 106
#
# Here are the frequent words from nubs-nob-ski-area
#
# nub 106
# ski 60
# lift 56
# snow 54
# run 53
#
# Here are the frequent words from powder-mountain
#
# powder 156
# mountain 130
# resort 74
# day 71
# ski 67
#
# Here are the frequent words from peekn-peak
#
# great 52
# ski 49
# peak 47
# place 42
# peek 40
#
# Here are the frequent words from aspen-snowmass
#
# aspen 82
# mountain 77
# great 60
# snowmass 59
# ski 46
#
# Here are the frequent words from mt-rose-ski-tahoe
#
# rose 54
# great 35
# ski 34
# mt 31
# run 26
#
# Here are the frequent words from indianhead-mountain
#
# great 105
# indianhead 94
# snow 92
# ski 73
# run 69
#
# Here are the frequent words from badger-pass
#
# yosemite 30
# ski 27
# lift 22
# great 19
# family 18
#
# Here are the frequent words from sugarloaf
#
# mountain 65
# sugarloaf 48
# great 44
# ski 39
# get 29
#
# Here are the frequent words from bridger-bowl
#
# bridger 48
# mountain 41
# lift 39
# terrain 38
# great 31
#
# Here are the frequent words from arapahoe-basin-ski-area
#
# mountain 108
# great 101
# resort 99
# run 98
# ski 98
#
# Here are the frequent words from donner-ski-ranch
#
# ski 69
# great 55
# lift 48
# donner 43
# place 41
#
# Here are the frequent words from chestnut-mountain-resort
#
# chestnut 46
# ski 45
# run 42
# resort 36
# lift 35
#
# Here are the frequent words from ski-granby-ranch
#
# ski 62
# great 43
# family 33
# time 28
# year 28
#
# Here are the frequent words from kirkwood
#
# kirkwood 166
# snow 98
# resort 87
# day 77
# tahoe 77
#
# Here are the frequent words from june-mountain
#
# june 61
# mountain 53
# great 39
# run 34
# mammoth 34
#
# Here are the frequent words from mt-abram-ski-resort
#
# mountain 30
# ski 23
# great 20
# mt 20
# family 17
#
# Here are the frequent words from loveland
#
# loveland 154
# lift 114
# ski 104
# great 77
# get 68
#
# Here are the frequent words from big-sky-resort
#
# big 204
# sky 173
# ski 126
# lift 124
# mountain 111
#
# Here are the frequent words from ski-snowstar-winter-sports-park
#
# lift 27
# ski 25
# snowstar 25
# time 24
# day 21
#
# Here are the frequent words from mount-ashland
#
# ski 23
# ashland 23
# great 17
# get 11
# mt 11
#
# Here are the frequent words from big-squaw-mountain-ski-resort
#
# great 16
# lift 9
# mountain 9
# skiing 7
# day 5
#
# Here are the frequent words from jackson-hole
#
# jackson 134
# mountain 113
# ski 107
# day 79
# great 73
#
# Here are the frequent words from snowbasin
#
# ski 106
# mountain 96
# snowbasin 89
# resort 86
# lift 73
#
# Here are the frequent words from deer-valley-resort
#
# valley 121
# deer 120
# ski 119
# resort 84
# day 77
#
# Here are the frequent words from shanty-creek
#
# ski 75
# resort 59
# schuss 57
# great 55
# lift 55
#
# Here are the frequent words from tahoe-donner
#
# ski 40
# great 36
# family 32
# kid 32
# place 30
#
# Here are the frequent words from monarch-mountain
#
# monarch 112
# mountain 67
# great 58
# snow 54
# lift 52
#
# Here are the frequent words from cannon-mountain
#
# mountain 81
# cannon 66
# day 43
# ski 41
# great 40
#
# Here are the frequent words from elk-mountain-ski-resort
#
# elk 224
# mountain 157
# lift 122
# ski 118
# trail 106
#
# Here are the frequent words from loon-mountain
#
# loon 101
# mountain 95
# great 79
# trail 62
# day 61
#
# Here are the frequent words from mt-baker
#
# baker 117
# snow 70
# mountain 67
# great 56
# day 55
#
# Here are the frequent words from holiday-valley
#
# resort 53
# skiing 44
# great 42
# lift 42
# good 38
#
# Here are the frequent words from pine-mountain
#
# great 74
# mountain 50
# ski 45
# pine 43
# family 35
#
# Here are the frequent words from coffee-mill-ski-snowboard-resort
#
# ski 13
# run 11
# skiing 8
# coffee 8
# good 7
#
# Here are the frequent words from beaver-creek
#
# creek 89
# beaver 87
# mountain 85
# ski 81
# great 76
#
# Here are the frequent words from gore-mountain
#
# gore 95
# mountain 92
# great 65
# trail 51
# lift 49
#
# Here are the frequent words from pine-knob-ski-resort
#
# good 12
# place 11
# get 10
# great 10
# hill 6
#
# Here are the frequent words from sugarbush
#
# sugarbush 142
# trail 101
# mountain 93
# great 88
# day 85
#
# Here are the frequent words from mohawk-mountain
#
# great 45
# mohawk 43
# mountain 37
# ski 34
# place 33
#
# Here are the frequent words from black-mountain
#
# mountain 59
# black 56
# family 29
# ski 29
# snow 21
#
# Here are the frequent words from mount-holly
#
# place 22
# holly 21
# great 18
# lift 18
# run 17
#
# Here are the frequent words from sierra-at-tahoe
#
# sierra 49
# run 46
# great 40
# day 38
# resort 30
#
# Here are the frequent words from jay-peak
#
# jay 202
# snow 133
# mountain 102
# skiing 86
# ski 82
#
# Here are the frequent words from copper-mountain-resort
#
# copper 208
# mountain 170
# great 130
# ski 114
# lift 104
# Here are the frequent words from sunlight-mountain-resort
#
# sunlight 38
# mountain 32
# ski 25
# great 23
# day 16
#
# Here are the frequent words from snowy-range-ski-recreation-area
#
# day 46
# ski 45
# great 40
# snowy 32
# place 30
#
# Here are the frequent words from pomerelle-mountain-resort
#
# great 39
# pomerelle 27
# resort 24
# snow 21
# ski 19
#
# Here are the frequent words from cranmore-mountain-resort
#
# mountain 28
# trail 23
# great 22
# cranmore 22
# skiing 15
#
# Here are the frequent words from steamboat
#
# steamboat 194
# mountain 122
# ski 108
# skiing 104
# great 100
#
# Here are the frequent words from crystal-mountain
#
# resort 37
# great 33
# crystal 33
# run 28
# ski 24
#
# Here are the frequent words from lookout-pass-ski-area
#
# lookout 76
# ski 54
# great 34
# mountain 33
# resort 29
#
# Here are the frequent words from ski-cooper
#
# ski 45
# day 32
# cooper 27
# great 26
# mountain 23
#
# Here are the frequent words from diamond-peak
#
# great 35
# run 35
# diamond 32
# peak 29
# view 21
#
# Here are the frequent words from pajarito-mountain-ski-area
#
# run 37
# great 36
# lift 36
# mountain 30
# ski 30
#
# Here are the frequent words from ski-sawmill
#
# ski 34
# sawmill 21
# lesson 18
# great 15
# place 15
#
# Here are the frequent words from snow-trails
#
# snow 33
# great 23
# trail 22
# nice 16
# place 16
#
# Here are the frequent words from canaan-valley-resort
#
# resort 45
# lift 34
# canaan 34
# great 30
# mountain 26
#
# Here are the frequent words from whitefish-mountain-resort
#
# mountain 112
# ski 73
# great 69
# snow 59
# lift 58
#
# Here are the frequent words from terry-peak-ski-area
#
# ski 18
# good 16
# terry 16
# great 15
# hill 14
#
# Here are the frequent words from eagle-point
#
# resort 28
# lift 26
# point 23
# eagle 23
# great 20
#
# Here are the frequent words from blue-knob
#
# knob 83
# blue 79
# mountain 63
# ski 59
# good 45
#
# Here are the frequent words from whiteface-mountain-resort
#
# mountain 138
# whiteface 108
# great 75
# trail 59
# ski 57
#
# Here are the frequent words from brighton-resort
#
# brighton 141
# resort 73
# great 72
# day 57
# ski 49
#
# Here are the frequent words from crotched-mountain
#
# mountain 51
# great 46
# lift 35
# crotched 34
# trail 29
#
# Here are the frequent words from silverton-mountain
#
# silverton 90
# ski 74
# day 73
# guide 63
# mountain 61
#
# Here are the frequent words from park-city-mountain-resort
#
# park 143
# ski 140
# city 132
# great 111
# lift 101
#
# Here are the frequent words from mammoth-mountain-ski-area
#
# mammoth 234
# mountain 185
# great 104
# snow 104
# ski 93
#
# Here are the frequent words from otis-ridge-ski-area
#
# great 15
# ski 15
# mountain 12
# otis 11
# beginner 10
#
# Here are the frequent words from breckenridge
#
# ski 170
# great 169
# peak 168
# mountain 160
# breck 150
#
# Here are the frequent words from mt-hood-ski-bowl
#
# ski 46
# bowl 44
# get 25
# lift 24
# night 24
#
# Here are the frequent words from boyne-highlands
#
# run 44
# great 32
# snow 30
# boyne 30
# lift 29
#
# Here are the frequent words from great-divide
#
# snow 41
# ski 38
# great 32
# hill 20
# divide 19
#
# Here are the frequent words from vail
#
# vail 416
# day 205
# ski 200
# get 158
# back 152
#
# Here are the frequent words from suicide-six
#
# ski 19
# mountain 16
# hill 12
# family 9
# resort 9
#
# Here are the frequent words from hogadon
#
# great 27
# casper 24
# ski 17
# city 15
# run 13
#
# Here are the frequent words from bear-valley
#
# bear 44
# mountain 40
# valley 35
# great 34
# ski 33
#
# Here are the frequent words from montana-snowbowl
#
# mountain 36
# ski 23
# lift 20
# good 18
# snow 17
#
# Here are the frequent words from sundance
#
# sundance 38
# resort 34
# ski 29
# mountain 21
# run 21
#
# Here are the frequent words from red-river
#
# red 108
# river 106
# ski 100
# great 86
# town 76
#
# Here are the frequent words from keystone
#
# keystone 236
# run 145
# resort 115
# ski 112
# great 110
#
# Here are the frequent words from mount-southington-ski-area
#
# ski 20
# southington 20
# great 19
# mountain 18
# go 16
#
# Here are the frequent words from mount-kato-ski-area
#
# good 24
# hill 11
# area 10
# lift 10
# kato 10
#
# Here are the frequent words from woods-valley-ski-area
#
# kid 15
# trail 12
# beginner 11
# hill 11
# place 11
#
# Here are the frequent words from crystal-mountain-wa
#
# crystal 155
# mountain 99
# ski 85
# terrain 73
# lift 70
#
# Here are the frequent words from brian-head-resort
#
# resort 79
# head 79
# brian 72
# lift 64
# ski 54
#
# Here are the frequent words from blue-hills-ski-area
#
# ski 20
# hill 16
# great 14
# blue 10
# area 9
#
# Here are the frequent words from winter-park-resort
#
# park 211
# ski 197
# winter 185
# mountain 172
# lift 165
#
# Here are the frequent words from lutsen-mountains
#
# lutsen 226
# run 184
# mountain 142
# ski 130
# snow 120
#
# Here are the frequent words from devils-head
#
# run 123
# great 83
# lift 66
# resort 64
# devil 64
#
# Here are the frequent words from perfect-north-slopes
#
# ski 97
# get 73
# lift 73
# perfect 68
# place 68
#
# Here are the frequent words from sun-valley
#
# valley 69
# sun 69
# mountain 55
# great 53
# snow 52
#
# Here are the frequent words from cascade-mountain
#
# cascade 77
# ski 75
# lift 62
# run 58
# great 53
#
# Here are the frequent words from sundown-mountain
#
# sundown 26
# good 22
# run 19
# better 18
# great 18
#
# Here are the frequent words from bretton-woods
#
# trail 78
# bretton 63
# wood 61
# great 60
# mountain 58
#
# Here are the frequent words from schweitzer
#
# mountain 70
# schweitzer 66
# snow 45
# ski 41
# day 38
#
# Here are the frequent words from dodge-ridge
#
# dodge 88
# ski 65
# day 49
# lift 47
# great 44
#
# Here are the frequent words from spirit-mountain
#
# spirit 133
# snow 86
# run 69
# mountain 60
# lift 39
#
# Here are the frequent words from sunday-river
#
# lift 92
# sunday 85
# river 83
# mountain 78
# great 75
#
# Here are the frequent words from solitude-mountain-resort
#
# solitude 146
# day 94
# ski 94
# lift 87
# great 70
#
# Here are the frequent words from snow-king-resort
#
# jackson 17
# snow 15
# hole 14
# steep 12
# king 12
#
# Here are the frequent words from bogus-basin
#
# bogus 63
# mountain 61
# good 30
# great 26
# skiing 26
#
# Here are the frequent words from tamarack-resort
#
# great 55
# tamarack 51
# run 37
# ski 37
# mountain 33
#
# Here are the frequent words from brandywine
#
# park 40
# great 36
# resort 27
# place 25
# brandywine 23
#
# Here are the frequent words from appalachian-ski-mtn
#
# ski 67
# place 46
# great 36
# resort 36
# kid 29
#
# Here are the frequent words from stowe-mountain-resort
#
# stowe 168
# mountain 92
# ski 81
# great 73
# lift 73
#
# Here are the frequent words from jiminy-peak
#
# day 65
# mountain 65
# great 60
# jiminy 51
# trail 48
#
# Here are the frequent words from boston-mills
#
# resort 38
# place 32
# good 31
# hill 31
# ski 29
#
# Here are the frequent words from belleayre
#
# lift 104
# mountain 104
# ski 103
# trail 87
# belleayre 79
#
# Here are the frequent words from alpental
#
# alpental 64
# terrain 40
# snow 39
# get 35
# great 28
#
# Here are the frequent words from timberline-lodge
#
# great 39
# timberline 37
# lodge 26
# run 25
# resort 21
#
# Here are the frequent words from snow-valley
#
# snow 86
# valley 56
# resort 51
# great 50
# lift 48
#
# Here are the frequent words from catamount-ski-ride-area
#
# catamount 68
# great 64
# mountain 58
# ski 42
# trail 42
#
# Here are the frequent words from bear-creek-mountain-resort
#
# mountain 78
# great 67
# place 59
# ski 58
# bear 58
#
# Here are the frequent words from caberfae-peaks-ski-golf-resort
#
# caberfae 53
# resort 41
# run 41
# ski 37
# place 36
#
# Here are the frequent words from dry-hill-ski-area
#
# hill 40
# ski 23
# dry 22
# small 12
# kid 10
#
# Here are the frequent words from bromley-mountain
#
# bromley 82
# mountain 56
# day 48
# ski 42
# great 40
#
# Here are the frequent words from whitecap-mountain
#
# whitecap 57
# run 48
# lift 46
# skiing 44
# ski 41
#
# Here are the frequent words from red-lodge-mountain
#
# lodge 48
# red 46
# mountain 41
# skiing 38
# snow 37
#
# Here are the frequent words from kelly-canyon-ski-area
#
# go 18
# ski 16
# good 13
# great 13
# place 13
#
# Here are the frequent words from giants-ridge-resort
#
# giant 37
# ridge 34
# ski 16
# go 13
# place 13
#
# Here are the frequent words from sno-mountain
#
# mountain 206
# lift 121
# sno 103
# trail 97
# great 93
#
# Here are the frequent words from bryce-resort
#
# resort 33
# bryce 31
# snow 24
# good 19
# ski 19
#
# Here are the frequent words from mount-holiday-ski-area
#
# place 14
# great 13
# holiday 11
# two 10
# mt 10
#
# Here are the frequent words from mount-peter-ski-area
#
# great 43
# time 40
# mountain 37
# place 36
# peter 34
#
# Here are the frequent words from blandford-ski-area
#
# lift 14
# day 13
# ski 11
# get 10
# great 10
#
# Here are the frequent words from eagle-rock
#
# resort 23
# trail 18
# rock 17
# family 15
# steep 15
#
# Here are the frequent words from smugglers-notch-resort
#
# lift 106
# mountain 78
# smuggs 77
# great 73
# ski 72
#
# Here are the frequent words from killington-resort
#
# killington 300
# mountain 213
# ski 172
# great 152
# trail 142
#
# Here are the frequent words from alyeska-resort
#
# alyeska 42
# place 28
# resort 27
# snow 26
# day 25
# Here are the frequent words from waterville-valley
#
# mountain 48
# trail 44
# waterville 40
# great 37
# day 31
#
# Here are the frequent words from pico-mountain-at-killington
#
# pico 65
# killington 53
# ski 43
# day 39
# mountain 37
#
# Here are the frequent words from bittersweet-ski-area
#
# lift 40
# bittersweet 36
# area 31
# run 29
# resort 27
#
# Here are the frequent words from nordic-mountain
#
# great 19
# good 18
# hill 17
# place 16
# run 13
#
# Here are the frequent words from durango-mountain-resort
#
# mountain 105
# durango 86
# lift 81
# ski 77
# great 76
#
# Here are the frequent words from okemo-mountain-resort
#
# okemo 178
# mountain 155
# trail 125
# lift 121
# ski 92
#
# Here are the frequent words from willamette-pass
#
# pas 80
# willamette 75
# lift 73
# ski 54
# get 53
#
# Here are the frequent words from mad-river-mountain
#
# park 73
# mad 72
# river 70
# ohio 53
# place 45
#
# Here are the frequent words from stratton-mountain
#
# stratton 182
# mountain 154
# lift 112
# trail 106
# ski 88
#
# Here are the frequent words from song-mountain
#
# song 19
# trail 18
# great 17
# good 14
# area 13
#
# Here are the frequent words from berkshire-east
#
# berkshire 34
# east 33
# mountain 26
# ski 23
# great 22
#
# Here are the frequent words from tyrol-basin
#
# tyrol 38
# lift 28
# park 25
# great 23
# hill 23
#
# Here are the frequent words from ski-sundown
#
# ski 38
# good 27
# sundown 27
# mountain 26
# place 23
#
# Here are the frequent words from bear-mountain
#
# bear 60
# mountain 47
# park 30
# day 28
# snow 28
#
# Here are the frequent words from attitash
#
# attitash 62
# peak 39
# great 34
# lift 33
# ski 32
#
# Here are the frequent words from pats-peak
#
# lift 49
# peak 39
# ski 36
# pat 34
# mountain 32
#
# Here are the frequent words from wolf-creek
#
# lift 15
# day 14
# great 13
# night 13
# mountain 12
#
# Here are the frequent words from angel-fire-resort
#
# ski 135
# fire 128
# angel 126
# great 113
# snow 112
#
# Here are the frequent words from wild-mountain-ski-snowboard-area
#
# wild 40
# run 33
# ski 27
# mountain 25
# get 16
#
# Here are the frequent words from snow-summit
#
# snow 79
# summit 52
# resort 48
# mountain 46
# great 44
#
# Here are the frequent words from sipapu-ski-and-summer-resort
#
# sipapu 59
# ski 50
# great 48
# day 36
# lift 36
#
# Here are the frequent words from ski-butternut
#
# great 54
# butternut 52
# ski 49
# trail 39
# day 37
#
# Here are the frequent words from andes-tower-hills-ski-area
#
# run 22
# great 19
# andes 18
# hill 17
# place 17
#
# Here are the frequent words from bousquet-ski-area
#
# mountain 15
# lift 14
# ski 12
# area 9
# day 7
#
# Here are the frequent words from boyne-mountain-resort
#
# boyne 60
# ski 57
# great 51
# lift 42
# skiing 41
#
# Here are the frequent words from ski-china-peak
#
# run 71
# resort 56
# sierra 56
# summit 50
# place 44
#
# Here are the frequent words from granite-peak-ski-area
#
# run 161
# lift 125
# granite 101
# peak 98
# ski 81
#
# Here are the frequent words from burke-mountain
#
# mountain 68
# burke 43
# trail 34
# lift 33
# ski 28
#
# Here are the frequent words from squaw-valley-usa
#
# squaw 148
# mountain 108
# lift 102
# resort 94
# day 81
#
# Here are the frequent words from paoli-peaks
#
# paoli 53
# ski 46
# place 34
# great 32
# snow 30
#
# Here are the frequent words from mount-shasta-board-ski-park
#
# lift 31
# shasta 25
# park 22
# ski 19
# time 17
#
# Here are the frequent words from bristol-mountain
#
# ski 69
# mountain 43
# area 37
# go 36
# bristol 36
#
# Here are the frequent words from swain
#
# swain 31
# skiing 22
# year 22
# great 21
# condition 14
#
# Here are the frequent words from shawnee-peak
#
# mountain 44
# shawnee 37
# great 32
# lift 25
# ski 25
#
# Here are the frequent words from snowshoe-mountain-resort
#
# snowshoe 239
# resort 158
# lift 157
# ski 145
# snow 139
#
# Here are the frequent words from jack-frost
#
# frost 60
# jack 60
# snow 54
# mountain 49
# ski 46
#
# Here are the frequent words from powder-ridge-ski-area
#
# great 10
# place 10
# good 8
# hill 6
# night 6
#
# Here are the frequent words from mt-baldy
#
# baldy 115
# snow 90
# lift 79
# mountain 69
# ski 66
#
# Here are the frequent words from windham-mountain
#
# mountain 54
# windham 54
# lift 40
# great 39
# trail 36
#
# Here are the frequent words from wisp
#
# wisp 123
# resort 72
# mountain 69
# ski 63
# day 58
#
# Here are the frequent words from bluewood
#
# bluewood 24
# run 20
# good 19
# lift 18
# great 17
#
# Here are the frequent words from alpine-valley-resort
#
# hill 58
# lift 58
# run 56
# good 54
# place 53
#
# Here are the frequent words from new-hermon-mountain
#
# mountain 19
# great 14
# lift 13
# really 13
# food 13
#
# Here are the frequent words from blue-mountain-ski-area
#
# mountain 268
# blue 256
# trail 158
# lift 156
# ski 136
#
# Here are the frequent words from timber-ridge
#
# ski 28
# park 25
# place 23
# hill 19
# run 16
#
# Here are the frequent words from massanutten
#
# resort 50
# ski 44
# massanutten 40
# great 36
# snow 36
#
# Here are the frequent words from ski-santa-fe
#
# ski 158
# lift 123
# fe 120
# santa 118
# mountain 101
#
# Here are the frequent words from silver-mountain
#
# silver 110
# mountain 94
# lift 90
# resort 69
# ski 65
#
# Here are the frequent words from tussey-mountain
#
# great 22
# tussey 22
# mountain 17
# place 16
# ski 14
#
# Here are the frequent words from wintergreen-resort
#
# wintergreen 90
# resort 68
# ski 67
# slope 56
# snow 55
#
# Here are the frequent words from sunburst
#
# hill 25
# run 20
# ski 19
# sunburst 19
# good 17
#
# Here are the frequent words from roundtop-mountain-resort
#
# ski 71
# roundtop 62
# snow 50
# trail 49
# area 48
#
# Here are the frequent words from big-boulder
#
# park 56
# mountain 38
# boulder 35
# big 32
# terrain 29
#
# Here are the frequent words from bolton-valley
#
# great 46
# bolton 31
# day 25
# ski 25
# mountain 23
#
# Here are the frequent words from heavenly-mountain-resort
#
# heavenly 206
# mountain 149
# lift 139
# ski 126
# get 115
#
# Here are the frequent words from northstar-california
#
# northstar 144
# run 107
# resort 94
# mountain 89
# day 85
#
# Here are the frequent words from cataloochee-ski-area
#
# ski 129
# time 62
# cataloochee 57
# snow 56
# lift 53
#
# Here are the frequent words from mount-sunapee
#
# sunapee 56
# mountain 55
# great 51
# day 47
# trail 40
#
# Here are the frequent words from mt-hood-meadows
#
# meadow 108
# ski 84
# get 70
# season 66
# great 65
#
# Here are the frequent words from brantling-ski-slopes
#
# ski 28
# place 18
# small 16
# brantling 14
# great 13
#
# Here are the frequent words from mount-snow
#
# snow 289
# mountain 162
# lift 134
# trail 115
# mount 115
#
# Here are the frequent words from greek-peak
#
# lift 64
# greek 58
# ski 41
# great 37
# mountain 35
#
# Here are the frequent words from willard-mountain
#
# kid 18
# willard 14
# great 12
# ski 11
# mountain 10
#
# Here are the frequent words from buck-hill
#
# hill 33
# buck 31
# great 24
# area 22
# ski 21
#
# Here are the frequent words from sunrise-park-resort
#
# sunrise 147
# ski 130
# lift 112
# mountain 106
# snow 98
#
# Here are the frequent words from gunstock
#
# mountain 45
# lift 40
# great 36
# get 32
# gunstock 31
#
# Here are the frequent words from labrador-mt
#
# great 15
# best 9
# park 9
# ski 7
# many 7
#
# Here are the frequent words from ski-beech-mountain-resort
#
# ski 98
# beech 93
# snow 71
# lift 59
# time 56
#
# Here are the frequent words from mt-bachelor
#
# lift 97
# bachelor 95
# mountain 92
# day 67
# ski 67
#
# Here are the frequent words from welch-village
#
# welch 66
# run 45
# ski 39
# area 38
# lift 32
#
# Here are the frequent words from marquette-mountain
#
# mountain 33
# ski 25
# great 23
# hill 23
# lift 23
#
# Here are the frequent words from afton-alps
#
# afton 78
# run 51
# area 33
# hill 33
# go 31
#
# Here are the frequent words from christmas-mountain
#
# place 31
# ski 29
# great 25
# line 24
# hill 20
#
# Here are the frequent words from ragged-mountain-resort
#
# mountain 69
# trail 68
# ragged 64
# lift 42
# one 40
#
# Here are the frequent words from magic-mountain-ski-area
#
# mountain 34
# magic 22
# run 22
# hill 15
# really 15
#
# Here are the frequent words from whitetail-resort
#
# whitetail 84
# ski 56
# snow 56
# lift 55
# day 54
#
# Here are the frequent words from shawnee-mountain-ski-area
#
# mountain 47
# shawnee 43
# ski 39
# trail 38
# good 37
#
# Here are the frequent words from ski-mystic-at-deer-mountain
#
# mountain 20
# ski 20
# great 19
# year 19
# deer 19
#
# Here are the frequent words from swiss-valley
#
# place 25
# ski 24
# swiss 22
# lift 21
# run 21
#
# Here are the frequent words from toggenburg-mountain
#
# ski 32
# tog 18
# lift 17
# son 16
# black 15
#
# Here are the frequent words from eldora-mountain-resort
#
# eldora 82
# ski 69
# resort 48
# get 47
# mountain 46
#
# Here are the frequent words from west-mountain
#
# mountain 43
# great 28
# ski 25
# lift 24
# trail 24
#
# Here are the frequent words from wachusett-mountain-ski-area
#
# mountain 95
# great 72
# ski 68
# get 62
# trail 57
#
# Here are the frequent words from boreal
#
# boreal 82
# board 59
# resort 49
# good 48
# lift 38
# Here are the frequent words from alpine-valley
#
# place 24
# lift 19
# good 16
# hill 13
# ski 12
#
# Here are the frequent words from wilmot-mountain
#
# wilmot 42
# ski 37
# lift 36
# place 36
# hill 34
#
# Here are the frequent words from arizona-snowbowl
#
# lift 106
# snowbowl 99
# snow 88
# ski 71
# get 66
#
# Here are the frequent words from stevens-pass-resort
#
# stevens 139
# pas 119
# ski 107
# mountain 85
# get 84
#
# Here are the frequent words from wolf-ridge-ski-resort
#
# ski 60
# lift 46
# slope 40
# get 32
# wolf 31
#
# Here are the frequent words from grand-geneva
#
# hill 20
# lift 20
# run 17
# grand 14
# geneva 14
#
# Here are the frequent words from kissing-bridge
#
# slope 27
# kb 26
# open 23
# lift 21
# holliday 20
#
# Here are the frequent words from hidden-valley-ski-area
#
# place 34
# ski 28
# snow 24
# skiing 22
# year 20
#
# Here are the frequent words from timberline-four-seasons
#
# lift 86
# timberline 77
# resort 67
# mountain 66
# trail 66
#
# Here are the frequent words from hunter-mountain
#
# hunter 185
# mountain 144
# snow 103
# trail 101
# ski 86
#
# Here are the frequent words from liberty
#
# liberty 83
# lift 66
# ski 62
# snow 59
# mountain 58
#
# Here are the frequent words from cooper-spur
#
# cooper 19
# spur 18
# ski 17
# kid 15
# would 15
#
# Here are the frequent words from 49-degrees-north
#
# ski 51
# lift 39
# mountain 38
# snow 36
# would 35
#
# Here are the frequent words from mountain-high
#
# resort 68
# get 67
# mountain 67
# snow 66
# time 62
#
# Here are the frequent words from snow-creek
#
# good 32
# park 32
# snow 25
# place 18
# run 18
#
# Here are the frequent words from soda-springs
#
# kid 35
# lift 30
# one 30
# tube 24
# staff 23
#
# Here are the frequent words from cannonsburg
#
# ski 62
# cannonsburg 55
# place 50
# lift 47
# get 37
#
# Here are the frequent words from the-summit-at-snoqualmie
#
# summit 53
# run 41
# ski 41
# great 40
# area 37
#
# Here are the frequent words from bradford-ski-area
#
# ski 22
# bradford 20
# mountain 15
# best 8
# hill 8
#
# Here are the frequent words from spring-mountain-ski-area
#
# mountain 68
# ski 63
# spring 50
# kid 48
# place 44
#
# Here are the frequent words from camelback-mountain-resort
#
# camelback 166
# mountain 164
# lift 156
# line 134
# trail 125
#
# Here are the frequent words from big-bear
#
# great 37
# big 34
# bear 33
# ski 31
# place 24
#
# Here are the frequent words from winterplace-ski-resort
#
# ski 71
# lift 62
# place 45
# winterplace 45
# go 42
#
# Here are the frequent words from mount-la-crosse
#
# ski 25
# place 20
# hill 18
# run 17
# terrain 15
#
# Here are the frequent words from villa-olivia
#
# resort 36
# go 24
# place 23
# ski 22
# slope 19
#
# Here are the frequent words from ski-apache
#
# ski 286
# snow 174
# apache 165
# lift 164
# mountain 139
#
# Here are the frequent words from las-vegas-ski-and-snowboard-resort
#
# place 51
# day 41
# vega 40
# lift 38
# snow 31
#
# Here are the frequent words from hyland-ski-snowboard-area
#
# place 21
# park 20
# terrain 17
# go 16
# hill 15
#
# Here are the frequent words from woodbury-ski-area
#
# ski 26
# place 22
# great 17
# woodbury 15
# like 14
#
# Here are the frequent words from sandia-peak
#
# lift 36
# ski 30
# snow 27
# mountain 23
# run 23
#
# Here are the frequent words from sugar-mountain-resort
#
# sugar 182
# lift 180
# snow 148
# ski 143
# day 126
#
# Here are the frequent words from ober-gatlinburg-ski-resort
#
# ski 55
# go 52
# slope 51
# ober 48
# time 46
#
# Here are the frequent words from mountain-creek-resort
#
# mountain 237
# creek 155
# lift 137
# get 125
# ski 109
#
# Here are the frequent words from mount-brighton
#
# lift 42
# mt 40
# ski 32
# place 31
# brighton 30
#
# Here are the frequent words from campgaw-mountain
#
# ski 37
# lift 21
# kid 19
# place 19
# mountain 18
#
# Here are the frequent words from whaleback-mountain
#
# trail 27
# need 19
# open 15
# could 12
# look 8
#
# Here are the frequent words from mt-crescent-ski-area
#
# lift 42
# snow 32
# place 26
# run 26
# one 25
#
# Here are the frequent words from holiday-mountain
#
# place 16
# ski 13
# hill 11
# like 11
# go 9

# %%
#  Here we perform TFIDF analysis based on the ski resorts. 
#  This takes a few seconds to process.

from gensim.models.tfidfmodel import TfidfModel

tfidf = TfidfModel(corpus_ski_areas)

# Calculate the tfidf weights of doc: tfidf_weights
print("\nTFIDF Analysis by Ski Resort:\n")
counter = 0
for doc in corpus_ski_areas:
    tfidf_weights = tfidf[doc]
    
    print('\n',ski_areas.index.values[counter]," key words and relative weights are:\n")
    counter +=1
    
    # Sort the weights from highest to lowest: sorted_tfidf_weights
    sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

    # Print the top 5 weighted words
    for term_id, weight in sorted_tfidf_weights[:5]:
        print(dictionary_ski_area.get(term_id), round(weight,3))

        
#  Here the name of ski center is often the most common words.  Also some trail names appear.
#  And some key ski center features also appear.  The lists are much more relevant by using
#  TFIDF.
# Out:
# TFIDF Analysis by Ski Resort:
#
#
#  blacktail-mountain-ski-area  key words and relative weights are:
#
# blacktail 0.807
# flathead 0.474
# fog 0.123
# whitefish 0.081
# exhange 0.059
#
#  blackjack-ski-resort  key words and relative weights are:
#
# blackjack 0.754
# fantasticly 0.189
# tohoe 0.189
# mighty 0.129
# anyplace 0.112
#
#  mad-river-glen  key words and relative weights are:
#
# mrg 0.678
# glen 0.236
# mad 0.23
# antelope 0.219
# river 0.169
#
#  ski-brule  key words and relative weights are:
#
# brule 0.963
# homestead 0.204
# bbq 0.07
# skiwee 0.031
# carload 0.027
#
#  magic-mountain  key words and relative weights are:
#
# magic 0.609
# vermont 0.237
# okemo 0.203
# bromley 0.166
# stratton 0.127
#
#  christie-mountain  key words and relative weights are:
#
# christie 0.759
# diffiulty 0.155
# pressured 0.155
# traisl 0.155
# terain 0.114
#
#  wildcat-mountain  key words and relative weights are:
#
# wildcat 0.805
# polecat 0.192
# washington 0.128
# pinkham 0.115
# cheetah 0.101
#
#  norway-mountain  key words and relative weights are:
#
# norway 0.583
# fried 0.161
# fish 0.152
# reopened 0.144
# clued 0.131
#
#  royal-mountain-ski-area  key words and relative weights are:
#
# royal 0.709
# laided 0.33
# moutian 0.266
# privately 0.202
# jim 0.196
#
#  anthony-lakes-mountain-resort  key words and relative weights are:
#
# anthony 0.567
# oregon 0.171
# aspirin 0.165
# haines 0.165
# quarterpipe 0.165
#
#  holimont-ski-area  key words and relative weights are:
#
# holimont 0.865
# burke 0.14
# ellicottville 0.14
# motorized 0.123
# weekday 0.085
#
#  brundage-mountain-resort  key words and relative weights are:
#
# brundage 0.828
# idaho 0.215
# mccall 0.143
# boise 0.09
# ole 0.09
#
#  mccauley-mountain-ski-center  key words and relative weights are:
#
# mccauley 0.869
# horible 0.132
# jeff 0.13
# tuning 0.121
# forge 0.116
#
#  beaver-mountain  key words and relative weights are:
#
# beav 0.835
# beaver 0.338
# logan 0.138
# skithebeav 0.138
# mm 0.099
#
#  eaglecrest-ski-area  key words and relative weights are:
#
# eaglecrest 0.793
# juneau 0.287
# alaska 0.198
# lindh 0.164
# elk 0.112
#
#  lost-trail-powder-mtn  key words and relative weights are:
#
# lost 0.404
# thoes 0.213
# montana 0.196
# missoula 0.172
# brutally 0.152
#
#  snow-ridge  key words and relative weights are:
#
# tug 0.191
# utica 0.191
# titus 0.175
# whiteface 0.174
# pod 0.164
#
#  big-powderhorn-mountain  key words and relative weights are:
#
# powderhorn 0.886
# caribou 0.201
# alpen 0.081
# midwest 0.076
# hideout 0.074
#
#  discovery-ski-area  key words and relative weights are:
#
# discovery 0.713
# georgetown 0.39
# montana 0.196
# disco 0.168
# anaconda 0.133
#
#  showdown-ski-area  key words and relative weights are:
#
# showdown 0.717
# everyweekend 0.179
# funn 0.157
# purest 0.144
# timely 0.144
#
#  telluride  key words and relative weights are:
#
# telluride 0.867
# montrose 0.128
# palmyra 0.119
# town 0.107
# village 0.086
#
#  bruce-mound  key words and relative weights are:
#
# mound 0.422
# bruce 0.388
# adjoining 0.269
# declan 0.269
# bluff 0.203
#
#  mission-ridge  key words and relative weights are:
#
# mission 0.854
# wenatchee 0.262
# ridge 0.153
# bomber 0.142
# liberator 0.09
#
#  sugar-bowl-resort  key words and relative weights are:
#
# sugar 0.636
# bowl 0.26
# squaw 0.251
# lincoln 0.215
# tahoe 0.185
#
#  pebble-creek-ski-area  key words and relative weights are:
#
# pebble 0.937
# stacy 0.088
# creek 0.088
# inkom 0.073
# pocatello 0.073
#
#  plattekill-mountain  key words and relative weights are:
#
# plattekill 0.798
# catskills 0.263
# belleayre 0.137
# windham 0.121
# hunter 0.104
#
#  grand-targhee-resort  key words and relative weights are:
#
# targhee 0.826
# teton 0.283
# grand 0.205
# driggs 0.152
# gt 0.123
#
#  hoodoo-ski-area  key words and relative weights are:
#
# hoodoo 0.865
# oregon 0.183
# willamette 0.144
# bachelor 0.112
# nìght 0.089
#
#  taos-ski-valley  key words and relative weights are:
#
# tao 0.935
# kachina 0.102
# tsv 0.094
# toas 0.063
# adobe 0.054
#
#  white-pass  key words and relative weights are:
#
# white 0.526
# crystal 0.299
# scenary 0.151
# whitepass 0.149
# wp 0.143
#
#  mount-bohemia  key words and relative weights are:
#
# bohemia 0.866
# midwest 0.185
# yurt 0.132
# houghton 0.126
# mount 0.077
#
#  wolf-creek-ski-area  key words and relative weights are:
#
# wolf 0.747
# creek 0.372
# pagosa 0.37
# alberta 0.233
# wc 0.108
#
#  soldier-mountain-ski-area  key words and relative weights are:
#
# soldier 0.81
# idaho 0.241
# soilder 0.141
# pop 0.134
# accommodates 0.124
#
#  powderhorn  key words and relative weights are:
#
# powderhorn 0.847
# mesa 0.152
# evident 0.095
# inviting 0.088
# quintessential 0.087
#
#  trollhaugen  key words and relative weights are:
#
# trollhaugen 0.882
# troll 0.272
# skyefall 0.156
# hudson 0.125
# festival 0.085
#
#  crested-butte-mountain-resort  key words and relative weights are:
#
# cb 0.648
# butte 0.49
# crested 0.446
# town 0.118
# gunnison 0.09
#
#  king-pine  key words and relative weights are:
#
# kp 0.397
# pine 0.359
# king 0.351
# thirty 0.286
# purity 0.198
#
#  snowbird  key words and relative weights are:
#
# snowbird 0.707
# mineral 0.379
# alta 0.232
# tram 0.219
# peruvian 0.201
#
#  titus-mountain  key words and relative weights are:
#
# titus 0.887
# whiteface 0.265
# calabogie 0.11
# syrup 0.089
# canadian 0.076
#
#  alta-ski-area  key words and relative weights are:
#
# alta 0.926
# collins 0.135
# snowbird 0.109
# supreme 0.082
# goldminer 0.077
#
#  nubs-nob-ski-area  key words and relative weights are:
#
# nub 0.862
# nob 0.317
# boyne 0.241
# pintail 0.13
# michigan 0.12
#
#  powder-mountain  key words and relative weights are:
#
# snowbasin 0.291
# josh 0.287
# ogden 0.255
# powmow 0.253
# utah 0.199
#
#  peekn-peak  key words and relative weights are:
#
# peek 0.728
# pknpk 0.441
# n 0.278
# peak 0.139
# pk 0.135
#
#  aspen-snowmass  key words and relative weights are:
#
# snowmass 0.69
# aspen 0.408
# buttermilk 0.297
# highland 0.264
# ajax 0.211
#
#  mt-rose-ski-tahoe  key words and relative weights are:
#
# rose 0.815
# reno 0.372
# tahoe 0.142
# squaw 0.119
# chute 0.11
#
#  indianhead-mountain  key words and relative weights are:
#
# indianhead 0.944
# suzanne 0.088
# midwest 0.076
# bikini 0.064
# powderhorn 0.063
#
#  badger-pass  key words and relative weights are:
#
# yosemite 0.837
# badger 0.433
# snowshoing 0.095
# veteran 0.066
# northstar 0.065
#
#  sugarloaf  key words and relative weights are:
#
# sugarloaf 0.849
# snowfield 0.207
# loaf 0.107
# skidder 0.104
# treeline 0.081
#
#  bridger-bowl  key words and relative weights are:
#
# bridger 0.86
# bozeman 0.263
# schlasman 0.141
# transceiver 0.099
# bowl 0.085
#
#  arapahoe-basin-ski-area  key words and relative weights are:
#
# basin 0.407
# montezuma 0.352
# arapahoe 0.252
# pallavicini 0.189
# loveland 0.169
#
#  donner-ski-ranch  key words and relative weights are:
#
# donner 0.617
# dsr 0.612
# ranch 0.376
# asks 0.057
# bud 0.052
#
#  chestnut-mountain-resort  key words and relative weights are:
#
# chestnut 0.82
# warpath 0.169
# mississippi 0.162
# midwest 0.14
# illinois 0.118
#
#  ski-granby-ranch  key words and relative weights are:
#
# sol 0.554
# granby 0.361
# solvista 0.361
# vista 0.343
# ranch 0.129
#
#  kirkwood  key words and relative weights are:
#
# kirkwood 0.943
# tahoe 0.183
# heavenly 0.084
# sierra 0.052
# lake 0.044
#
#  june-mountain  key words and relative weights are:
#
# june 0.848
# mammoth 0.364
# interlaken 0.088
# andestination 0.059
# righteous 0.059
#
#  mt-abram-ski-resort  key words and relative weights are:
#
# abram 0.808
# abrahm 0.215
# abrams 0.142
# mt 0.115
# approachable 0.111
#
#  loveland  key words and relative weights are:
#
# loveland 0.948
# denver 0.102
# divide 0.062
# continental 0.057
# windy 0.048
#
#  big-sky-resort  key words and relative weights are:
#
# sky 0.507
# lone 0.44
# moonlight 0.369
# tram 0.208
# bozeman 0.175
#
#  ski-snowstar-winter-sports-park  key words and relative weights are:
#
# snowstar 0.878
# wendy 0.194
# illinois 0.105
# chicago 0.081
# burbs 0.08
#
#  mount-ashland  key words and relative weights are:
#
# ashland 0.88
# bachelor 0.112
# benjamin 0.112
# complainer 0.09
# drunken 0.09
#
#  big-squaw-mountain-ski-resort  key words and relative weights are:
#
# greenville 0.505
# yosemite 0.294
# moosehead 0.294
# marriott 0.22
# b 0.18
#
#  jackson-hole  key words and relative weights are:
#
# jackson 0.597
# tram 0.36
# hole 0.195
# hobacks 0.193
# teton 0.168
#
#  snowbasin  key words and relative weights are:
#
# snowbasin 0.827
# gondola 0.176
# strawberry 0.144
# ogden 0.134
# cottonwood 0.099
#
#  deer-valley-resort  key words and relative weights are:
#
# deer 0.74
# dv 0.406
# valley 0.227
# canyon 0.115
# carpenter 0.077
#
#  shanty-creek  key words and relative weights are:
#
# schuss 0.636
# shanty 0.53
# bellaire 0.2
# michigan 0.181
# ivan 0.16
#
#  tahoe-donner  key words and relative weights are:
#
# donner 0.49
# fpr 0.221
# amd 0.178
# art 0.17
# spanish 0.158
#
#  monarch-mountain  key words and relative weights are:
#
# monarch 0.923
# mirkwood 0.18
# salida 0.166
# gunnison 0.073
# divide 0.05
#
#  cannon-mountain  key words and relative weights are:
#
# cannon 0.815
# mittersill 0.288
# tram 0.143
# tuckerbrook 0.105
# zoomer 0.105
#
#  elk-mountain-ski-resort  key words and relative weights are:
#
# elk 0.919
# pa 0.209
# sno 0.096
# camelback 0.081
# pennsylvania 0.08
#
#  loon-mountain  key words and relative weights are:
#
# loon 0.89
# ripsaw 0.115
# gondola 0.101
# nh 0.093
# peak 0.082
#
#  mt-baker  key words and relative weights are:
#
# baker 0.941
# mt 0.065
# bellingham 0.064
# shuksan 0.064
# stevens 0.056
#
#  holiday-valley  key words and relative weights are:
#
# hv 0.689
# ellicottville 0.27
# mound 0.145
# tannenbaum 0.139
# holiday 0.131
#
#  pine-mountain  key words and relative weights are:
#
# pine 0.696
# famers 0.148
# condo 0.109
# birthday 0.106
# brule 0.101
#
#  coffee-mill-ski-snowboard-resort  key words and relative weights are:
#
# mill 0.355
# coffee 0.255
# cushioning 0.21
# hangar 0.21
# octangular 0.21
#
#  beaver-creek  key words and relative weights are:
#
# beaver 0.569
# creek 0.335
# grouse 0.283
# avon 0.279
# bc 0.255
#
#  gore-mountain  key words and relative weights are:
#
# gore 0.879
# burnt 0.129
# saratoga 0.103
# gondola 0.09
# twister 0.077
#
#  pine-knob-ski-resort  key words and relative weights are:
#
# knob 0.309
# shaboom 0.308
# brighton 0.232
# vert 0.219
# pine 0.203
#
#  sugarbush  key words and relative weights are:
#
# sugarbush 0.722
# ellen 0.369
# castlerock 0.291
# lincoln 0.226
# organgrinder 0.078
#
#  mohawk-mountain  key words and relative weights are:
#
# mohawk 0.868
# ct 0.202
# sundown 0.137
# liar 0.094
# voucher 0.078
#
#  black-mountain  key words and relative weights are:
#
# passport 0.408
# hampshire 0.239
# dependent 0.169
# aging 0.155
# reselling 0.138
#
#  mount-holly  key words and relative weights are:
#
# holly 0.82
# michigan 0.24
# mount 0.132
# se 0.122
# sheeshhh 0.119
#
#  sierra-at-tahoe  key words and relative weights are:
#
# sierra 0.716
# tahoe 0.245
# pirate 0.156
# heavenly 0.14
# slipper 0.112
#
#  jay-peak  key words and relative weights are:
#
# jay 0.928
# tram 0.138
# glade 0.086
# peak 0.071
# canadian 0.061
#
#  copper-mountain-resort  key words and relative weights are:
#
# copper 0.885
# tucker 0.175
# village 0.121
# bee 0.092
# flyer 0.081
#
#  sunlight-mountain-resort  key words and relative weights are:
#
# sunlight 0.915
# glenwood 0.148
# stole 0.093
# brettleberg 0.073
# erich 0.073
#
#  snowy-range-ski-recreation-area  key words and relative weights are:
#
# snowy 0.63
# range 0.26
# centennial 0.177
# laramie 0.154
# definatly 0.117
#
#  pomerelle-mountain-resort  key words and relative weights are:
#
# pomerelle 0.939
# idaho 0.114
# turnoff 0.065
# appprox 0.043
# bashful 0.043
#
#  cranmore-mountain-resort  key words and relative weights are:
#
# cranmore 0.847
# arial 0.117
# bandit 0.117
# flipped 0.103
# disapointing 0.089
#  steamboat  key words and relative weights are:
#
# steamboat 0.935
# morningside 0.108
# town 0.061
# gondola 0.061
# colorado 0.053
#
#  crystal-mountain  key words and relative weights are:
#
# crystal 0.618
# michigan 0.348
# caberfae 0.237
# boyne 0.195
# fitness 0.141
#
#  lookout-pass-ski-area  key words and relative weights are:
#
# lookout 0.929
# brundage 0.08
# hercules 0.073
# phil 0.059
# charley 0.049
#
#  ski-cooper  key words and relative weights are:
#
# cooper 0.775
# leadville 0.288
# division 0.247
# veteran 0.147
# war 0.128
#
#  diamond-peak  key words and relative weights are:
#
# tahoe 0.367
# dp 0.253
# peak 0.213
# incline 0.196
# lake 0.168
#
#  pajarito-mountain-ski-area  key words and relative weights are:
#
# pajarito 0.658
# fe 0.266
# alamo 0.261
# santa 0.253
# los 0.185
#
#  ski-sawmill  key words and relative weights are:
#
# sawmill 0.927
# bunkhouse 0.081
# toboggan 0.081
# expects 0.076
# consequence 0.076
#
#  snow-trails  key words and relative weights are:
#
# ohio 0.515
# snowtrails 0.285
# cooling 0.228
# rimfire 0.186
# loft 0.163
#
#  canaan-valley-resort  key words and relative weights are:
#
# canaan 0.744
# timberline 0.224
# wv 0.188
# sanford 0.16
# davis 0.145
#
#  whitefish-mountain-resort  key words and relative weights are:
#
# whitefish 0.815
# fog 0.232
# hellroaring 0.144
# kalispell 0.133
# foggy 0.116
#
#  terry-peak-ski-area  key words and relative weights are:
#
# terry 0.828
# afforable 0.233
# coziest 0.145
# rearing 0.145
# unavaible 0.145
#
#  eagle-point  key words and relative weights are:
#
# eagle 0.608
# brianhead 0.293
# unit 0.282
# point 0.192
# bruh 0.155
#
#  blue-knob  key words and relative weights are:
#
# knob 0.887
# pa 0.115
# stembogan 0.107
# studio 0.095
# extrovert 0.094
#
#  whiteface-mountain-resort  key words and relative weights are:
#
# whiteface 0.859
# placid 0.326
# wilmington 0.108
# lake 0.081
# olympic 0.079
#
#  brighton-resort  key words and relative weights are:
#
# brighton 0.94
# millicent 0.16
# milly 0.133
# slc 0.068
# snowbird 0.055
#
#  crotched-mountain  key words and relative weights are:
#
# crotched 0.802
# cray 0.198
# boston 0.154
# wachusett 0.141
# choclates 0.099
#
#  silverton-mountain  key words and relative weights are:
#
# silverton 0.77
# guide 0.401
# unguided 0.18
# heli 0.124
# backcountry 0.078
#
#  park-city-mountain-resort  key words and relative weights are:
#
# pcmr 0.659
# city 0.326
# jupiter 0.247
# pc 0.18
# canyon 0.176
#
#  mammoth-mountain-ski-area  key words and relative weights are:
#
# mammoth 0.928
# mccoy 0.067
# socal 0.063
# cornice 0.047
# california 0.046
#
#  otis-ridge-ski-area  key words and relative weights are:
#
# otis 0.585
# wire 0.281
# coil 0.247
# brownish 0.141
# bulley 0.141
#
#  breckenridge  key words and relative weights are:
#
# breck 0.661
# breckenridge 0.492
# imperial 0.26
# peak 0.178
# town 0.098
#
#  mt-hood-ski-bowl  key words and relative weights are:
#
# hood 0.385
# skibowl 0.337
# bowl 0.33
# meadow 0.238
# outback 0.217
#
#  boyne-highlands  key words and relative weights are:
#
# boyne 0.534
# nub 0.448
# highland 0.442
# nob 0.295
# bh 0.209
#
#  great-divide  key words and relative weights are:
#
# divide 0.668
# rawhide 0.275
# helena 0.206
# belmont 0.166
# wild 0.108
#
#  vail  key words and relative weights are:
#
# vail 0.797
# bowl 0.206
# lionshead 0.195
# basin 0.13
# sky 0.118
#
#  suicide-six  key words and relative weights are:
#
# suicide 0.437
# woodstock 0.254
# lent 0.193
# skiway 0.193
# teago 0.193
#
#  hogadon  key words and relative weights are:
#
# casper 0.791
# hogadon 0.395
# hogadons 0.225
# ratty 0.198
# replacing 0.113
#
#  bear-valley  key words and relative weights are:
#
# bear 0.543
# cub 0.257
# grizzly 0.213
# sierra 0.191
# valley 0.175
#
#  montana-snowbowl  key words and relative weights are:
#
# snowbowl 0.604
# missoula 0.285
# pizza 0.142
# bowl 0.142
# selfies 0.141
#
#  sundance  key words and relative weights are:
#
# sundance 0.88
# nostalgic 0.121
# redford 0.12
# robert 0.091
# foundry 0.08
#
#  red-river  key words and relative weights are:
#
# red 0.64
# river 0.496
# rr 0.335
# tao 0.135
# town 0.134
#
#  keystone  key words and relative weights are:
#
# keystone 0.864
# outback 0.235
# dercum 0.176
# gondola 0.098
# schoolmarm 0.097
#
#  mount-southington-ski-area  key words and relative weights are:
#
# southington 0.872
# ct 0.254
# jjt 0.099
# sundown 0.089
# dom 0.087
#
#  mount-kato-ski-area  key words and relative weights are:
#
# kato 0.719
# sioux 0.217
# mn 0.197
# mankato 0.189
# bestt 0.144
#
#  woods-valley-ski-area  key words and relative weights are:
#
# glogging 0.323
# steered 0.283
# judging 0.221
# pie 0.205
# zone 0.198
#
#  crystal-mountain-wa  key words and relative weights are:
#
# crystal 0.847
# snorting 0.136
# northway 0.132
# rainier 0.132
# washington 0.132
#
#  brian-head-resort  key words and relative weights are:
#
# brian 0.768
# bh 0.366
# brianhead 0.244
# navajo 0.171
# vega 0.124
#
#  blue-hills-ski-area  key words and relative weights are:
#
# yell 0.35
# bluehills 0.265
# monopolized 0.265
# boston 0.258
# certification 0.233
#
#  winter-park-resort  key words and relative weights are:
#
# jane 0.574
# wp 0.545
# mary 0.327
# mj 0.181
# parsenn 0.127
#
#  lutsen-mountains  key words and relative weights are:
#
# lutsen 0.858
# moose 0.287
# papa 0.149
# eagle 0.121
# caribou 0.106
#
#  devils-head  key words and relative weights are:
#
# devil 0.755
# cascade 0.167
# wisconsin 0.144
# granite 0.135
# head 0.132
#
#  perfect-north-slopes  key words and relative weights are:
#
# pns 0.722
# indiana 0.176
# lawrenceburg 0.128
# north 0.123
# clyde 0.102
#
#  sun-valley  key words and relative weights are:
#
# ketchum 0.463
# baldy 0.384
# sun 0.322
# valley 0.242
# hailey 0.143
#
#  cascade-mountain  key words and relative weights are:
#
# cascade 0.835
# midwest 0.158
# cindy 0.147
# wisconsin 0.128
# chicago 0.113
#
#  sundown-mountain  key words and relative weights are:
#
# sundown 0.744
# chestnut 0.458
# iowa 0.165
# arkansas 0.096
# handywork 0.096
#
#  bretton-woods  key words and relative weights are:
#
# bretton 0.82
# wood 0.237
# bw 0.193
# rosebrook 0.128
# glade 0.109
#
#  schweitzer  key words and relative weights are:
#
# schweitzer 0.878
# sandpoint 0.175
# selkirk 0.087
# pend 0.065
# detreed 0.057
#
#  dodge-ridge  key words and relative weights are:
#
# dodge 0.883
# tahoe 0.148
# ridge 0.113
# dodgeridge 0.091
# pinecrest 0.091
#
#  spirit-mountain  key words and relative weights are:
#
# spirit 0.827
# gandy 0.234
# moosehead 0.175
# lutsen 0.169
# duluth 0.153
#
#  sunday-river  key words and relative weights are:
#
# jordan 0.468
# river 0.414
# barker 0.301
# oz 0.212
# aurora 0.208
#
#  solitude-mountain-resort  key words and relative weights are:
#
# solitude 0.847
# honeycomb 0.319
# canyon 0.142
# brighton 0.104
# moonbeam 0.102
#
#  snow-king-resort  key words and relative weights are:
#
# jackson 0.452
# king 0.445
# hole 0.271
# mounntain 0.21
# til 0.191
#
#  bogus-basin  key words and relative weights are:
#
# bogus 0.851
# boise 0.289
# basin 0.123
# insurance 0.103
# trampoline 0.057
#
#  tamarack-resort  key words and relative weights are:
#
# tamarack 0.832
# brundage 0.332
# bogus 0.128
# idaho 0.121
# boise 0.114
#
#  brandywine  key words and relative weights are:
#
# brandywine 0.815
# mill 0.247
# ohio 0.22
# boston 0.171
# bmbw 0.1
#
#  appalachian-ski-mtn  key words and relative weights are:
#
# appalachian 0.619
# app 0.372
# sugar 0.197
# debit 0.177
# beech 0.152
#
#  stowe-mountain-resort  key words and relative weights are:
#
# stowe 0.862
# spruce 0.205
# mansfield 0.182
# goat 0.119
# gondola 0.097
#
#  jiminy-peak  key words and relative weights are:
#
# jiminy 0.754
# jp 0.241
# berkshire 0.154
# skiwee 0.119
# jason 0.113
#
#  boston-mills  key words and relative weights are:
#
# bmbw 0.407
# brandywine 0.406
# mill 0.384
# tiger 0.283
# boston 0.238
#
#  belleayre  key words and relative weights are:
#
# belleayre 0.835
# hunter 0.169
# tomahawk 0.163
# superchief 0.146
# windham 0.122
#
#  alpental  key words and relative weights are:
#
# alpental 0.918
# snoqualmie 0.137
# nash 0.133
# bk 0.107
# alpy 0.095
#
#  timberline-lodge  key words and relative weights are:
#
# timberline 0.722
# hood 0.232
# skibowl 0.169
# oregon 0.151
# palmer 0.143
#
#  snow-valley  key words and relative weights are:
#
# bear 0.326
# valley 0.308
# sunlight 0.185
# smoking 0.133
# cal 0.126
#
#  catamount-ski-ride-area  key words and relative weights are:
#
# catamount 0.913
# butternut 0.165
# catapult 0.108
# barrington 0.09
# cultured 0.082
#
#  bear-creek-mountain-resort  key words and relative weights are:
#
# bear 0.515
# creek 0.34
# doe 0.237
# pa 0.188
# sasquatch 0.147
#
#  caberfae-peaks-ski-golf-resort  key words and relative weights are:
#
# caberfae 0.82
# crystal 0.264
# boyne 0.179
# michigan 0.167
# dub 0.129
#
#  dry-hill-ski-area  key words and relative weights are:
#
# dry 0.551
# titus 0.352
# insrtucters 0.218
# givin 0.176
# isa 0.176
#
#  bromley-mountain  key words and relative weights are:
#
# bromley 0.938
# stratton 0.091
# stargazer 0.064
# vermont 0.062
# manchester 0.052
#
#  whitecap-mountain  key words and relative weights are:
#
# whitecap 0.888
# powderhorn 0.164
# indianhead 0.141
# cap 0.084
# southside 0.082
#
#  red-lodge-mountain  key words and relative weights are:
#
# red 0.489
# rlm 0.398
# cole 0.289
# bridger 0.206
# palisade 0.191
#
#  kelly-canyon-ski-area  key words and relative weights are:
#
# kelly 0.707
# kelleys 0.269
# rexburg 0.236
# canyon 0.157
# idaho 0.152
#
#  giants-ridge-resort  key words and relative weights are:
#
# giant 0.686
# lutsen 0.308
# ridge 0.287
# reccomendation 0.186
# wynne 0.173
#
#  sno-mountain  key words and relative weights are:
#
# sno 0.651
# montage 0.634
# lightning 0.117
# elk 0.092
# pa 0.085
#
#  bryce-resort  key words and relative weights are:
#
# bryce 0.918
# horst 0.118
# va 0.085
# virginia 0.084
# nc 0.067
#
#  mount-holiday-ski-area  key words and relative weights are:
#
# traverse 0.281
# policy 0.23
# realise 0.227
# grandeur 0.209
# zipline 0.195
#
#  mount-peter-ski-area  key words and relative weights are:
#
# peter 0.811
# tuxedo 0.109
# mount 0.101
# hermon 0.096
# mt 0.089
#  blandford-ski-area  key words and relative weights are:
#
# blandford 0.533
# stormed 0.213
# wonky 0.213
# commend 0.166
# pico 0.166
#
#  eagle-rock  key words and relative weights are:
#
# eagle 0.475
# seating 0.25
# frost 0.22
# dirt 0.209
# allocate 0.186
#
#  smugglers-notch-resort  key words and relative weights are:
#
# smuggs 0.64
# madonna 0.457
# smuggler 0.251
# morse 0.228
# stowe 0.187
#
#  killington-resort  key words and relative weights are:
#
# killington 0.854
# pico 0.193
# snowshed 0.103
# powdr 0.091
# gondola 0.086
#
#  alyeska-resort  key words and relative weights are:
#
# alyeska 0.801
# anchorage 0.303
# aly 0.202
# girdwood 0.177
# ak 0.145
#
#  waterville-valley  key words and relative weights are:
#
# waterville 0.787
# wv 0.189
# bretten 0.128
# schwendi 0.128
# loon 0.106
#
#  pico-mountain-at-killington  key words and relative weights are:
#
# pico 0.882
# killington 0.319
# activated 0.079
# representative 0.067
# ka 0.06
#
#  bittersweet-ski-area  key words and relative weights are:
#
# bittersweet 0.796
# timber 0.184
# michigan 0.163
# cannonsburg 0.161
# timberridge 0.153
#
#  nordic-mountain  key words and relative weights are:
#
# nordic 0.572
# footer 0.316
# ahem 0.22
# atomsphere 0.22
# wisco 0.193
#
#  durango-mountain-resort  key words and relative weights are:
#
# durango 0.726
# dmr 0.496
# purgatory 0.295
# purg 0.079
# tamarron 0.06
#
#  okemo-mountain-resort  key words and relative weights are:
#
# okemo 0.874
# gore 0.269
# jackson 0.139
# ludlow 0.123
# killington 0.064
#
#  willamette-pass  key words and relative weights are:
#
# willamette 0.879
# eugene 0.16
# wp 0.115
# oakridge 0.102
# oregon 0.099
#
#  mad-river-mountain  key words and relative weights are:
#
# ohio 0.484
# mad 0.434
# mrm 0.381
# river 0.326
# madriver 0.301
#
#  stratton-mountain  key words and relative weights are:
#
# stratton 0.905
# gondola 0.125
# ursa 0.102
# ev 0.091
# village 0.06
#
#  song-mountain  key words and relative weights are:
#
# song 0.822
# syracuse 0.239
# sentimental 0.167
# defiantly 0.142
# deffanatlly 0.126
#
#  berkshire-east  key words and relative weights are:
#
# berkshire 0.834
# east 0.136
# jiminy 0.13
# chief 0.107
# england 0.094
#
#  tyrol-basin  key words and relative weights are:
#
# tyrol 0.912
# basin 0.161
# wisconsin 0.135
# cable 0.07
# accress 0.07
#
#  ski-sundown  key words and relative weights are:
#
# sundown 0.811
# ct 0.233
# mohawk 0.124
# gunbarrel 0.122
# lil 0.114
#
#  bear-mountain  key words and relative weights are:
#
# bear 0.683
# cal 0.159
# yur 0.142
# mammoth 0.137
# blackout 0.109
#
#  attitash  key words and relative weights are:
#
# attitash 0.907
# bear 0.131
# bretton 0.106
# peak 0.09
# triple 0.075
#
#  pats-peak  key words and relative weights are:
#
# pat 0.705
# hurricane 0.399
# mesh 0.151
# peak 0.138
# metal 0.091
#
#  wolf-creek  key words and relative weights are:
#
# snowbasin 0.503
# wolf 0.311
# exhillirating 0.205
# intermitently 0.205
# reponse 0.205
#
#  angel-fire-resort  key words and relative weights are:
#
# angel 0.773
# af 0.329
# fire 0.315
# tao 0.151
# mexico 0.133
#
#  wild-mountain-ski-snowboard-area  key words and relative weights are:
#
# wild 0.765
# afton 0.299
# noticeably 0.175
# welch 0.112
# alp 0.111
#
#  snow-summit  key words and relative weights are:
#
# summit 0.373
# bear 0.332
# socal 0.177
# westridge 0.134
# california 0.128
#
#  sipapu-ski-and-summer-resort  key words and relative weights are:
#
# sipapu 0.923
# tao 0.103
# fe 0.088
# santa 0.084
# teacher 0.069
#
#  ski-butternut  key words and relative weights are:
#
# butternut 0.883
# catamount 0.251
# nuthatch 0.059
# overrated 0.056
# jiminy 0.052
#
#  andes-tower-hills-ski-area  key words and relative weights are:
#
# andes 0.884
# tower 0.136
# haiwian 0.112
# chalet 0.1
# te 0.098
#
#  bousquet-ski-area  key words and relative weights are:
#
# bosquet 0.521
# bousquet 0.35
# comer 0.263
# pittsfield 0.261
# bouquet 0.174
#
#  boyne-mountain-resort  key words and relative weights are:
#
# boyne 0.818
# mclouth 0.183
# michigan 0.162
# hemlock 0.118
# museum 0.107
#
#  ski-china-peak  key words and relative weights are:
#
# sierra 0.63
# china 0.475
# summit 0.212
# fresno 0.122
# mammoth 0.121
#
#  granite-peak-ski-area  key words and relative weights are:
#
# granite 0.736
# gp 0.321
# midwest 0.247
# peak 0.16
# wi 0.125
#
#  burke-mountain  key words and relative weights are:
#
# burke 0.894
# initiated 0.11
# jay 0.088
# quiros 0.082
# willoughby 0.082
#
#  squaw-valley-usa  key words and relative weights are:
#
# squaw 0.853
# tahoe 0.21
# chief 0.104
# shirley 0.095
# kt 0.095
#
#  paoli-peaks  key words and relative weights are:
#
# paoli 0.936
# indiana 0.115
# louisville 0.082
# snowshoe 0.062
# lick 0.062
#
#  mount-shasta-board-ski-park  key words and relative weights are:
#
# shasta 0.907
# washboard 0.096
# scammer 0.084
# mt 0.082
# coyote 0.073
#
#  bristol-mountain  key words and relative weights are:
#
# bristol 0.801
# swain 0.164
# rochester 0.136
# hunt 0.111
# rocket 0.095
#
#  swain  key words and relative weights are:
#
# swain 0.906
# raving 0.143
# robinson 0.117
# favorable 0.082
# facebook 0.068
#
#  shawnee-peak  key words and relative weights are:
#
# shawnee 0.885
# conway 0.087
# joyless 0.075
# bridgton 0.075
# cosmetic 0.075
#
#  snowshoe-mountain-resort  key words and relative weights are:
#
# snowshoe 0.777
# territory 0.181
# silver 0.161
# silvercreek 0.146
# cupp 0.137
#
#  jack-frost  key words and relative weights are:
#
# frost 0.715
# jack 0.548
# jf 0.21
# boulder 0.139
# camelback 0.126
#
#  powder-ridge-ski-area  key words and relative weights are:
#
# advenced 0.422
# bords 0.422
# mae 0.37
# throught 0.302
# stride 0.277
#
#  mt-baldy  key words and relative weights are:
#
# baldy 0.925
# socal 0.164
# mt 0.079
# psych 0.054
# waterman 0.054
#
#  windham-mountain  key words and relative weights are:
#
# windham 0.821
# hunter 0.353
# catskills 0.091
# nyc 0.082
# waffle 0.073
#
#  wisp  key words and relative weights are:
#
# wisp 0.962
# dc 0.074
# coaster 0.058
# maryland 0.039
# ace 0.034
#
#  bluewood  key words and relative weights are:
#
# bluewood 0.914
# dayton 0.166
# huckleberry 0.094
# tucannon 0.094
# fin 0.068
#
#  alpine-valley-resort  key words and relative weights are:
#
# alpine 0.461
# chicago 0.339
# wisconsin 0.286
# devil 0.174
# valley 0.159
#
#  new-hermon-mountain  key words and relative weights are:
#
# hermon 0.451
# bangor 0.411
# camden 0.206
# parrallel 0.206
# trailblaze 0.206
#
#  blue-mountain-ski-area  key words and relative weights are:
#
# pa 0.353
# blue 0.268
# burma 0.235
# poconos 0.173
# razor 0.142
#
#  timber-ridge  key words and relative weights are:
#
# bittersweet 0.521
# timber 0.39
# sw 0.347
# michigan 0.255
# mi 0.113
#
#  massanutten  key words and relative weights are:
#
# massanutten 0.829
# harrisonburg 0.231
# waterpark 0.124
# dc 0.087
# mouse 0.079
#
#  ski-santa-fe  key words and relative weights are:
#
# fe 0.684
# santa 0.638
# tao 0.132
# mexico 0.084
# millenium 0.072
#
#  silver-mountain  key words and relative weights are:
#
# silver 0.791
# kellogg 0.211
# schweitzer 0.197
# gondola 0.189
# lookout 0.12
#
#  tussey-mountain  key words and relative weights are:
#
# tussey 0.933
# fulfills 0.085
# snowtube 0.085
# laugh 0.081
# barreling 0.078
#
#  wintergreen-resort  key words and relative weights are:
#
# wintergreen 0.919
# illness 0.103
# virginia 0.065
# winery 0.062
# snowshoe 0.057
#
#  sunburst  key words and relative weights are:
#
# sunburst 0.855
# moly 0.126
# tinny 0.126
# milwaukee 0.119
# psia 0.115
#
#  roundtop-mountain-resort  key words and relative weights are:
#
# roundtop 0.838
# lafayette 0.192
# minuteman 0.169
# liberty 0.148
# ramrod 0.107
#
#  big-boulder  key words and relative weights are:
#
# boulder 0.602
# bb 0.519
# jf 0.205
# jfbb 0.16
# frost 0.151
#
#  bolton-valley  key words and relative weights are:
#
# bolton 0.906
# bv 0.11
# burlington 0.088
# valley 0.071
# wilderness 0.07
#
#  heavenly-mountain-resort  key words and relative weights are:
#
# heavenly 0.792
# nevada 0.252
# gondola 0.205
# tahoe 0.17
# casino 0.132
#
#  northstar-california  key words and relative weights are:
#
# northstar 0.904
# village 0.128
# backside 0.102
# squaw 0.101
# tahoe 0.088
#
#  cataloochee-ski-area  key words and relative weights are:
#
# cataloochee 0.826
# maggie 0.231
# nc 0.159
# atlanta 0.128
# louse 0.098
#
#  mount-sunapee  key words and relative weights are:
#
# sunapee 0.856
# sunbowl 0.18
# boston 0.13
# signup 0.112
# mount 0.093
#
#  mt-hood-meadows  key words and relative weights are:
#
# meadow 0.672
# hood 0.441
# heather 0.254
# canyon 0.134
# portland 0.099
#
#  brantling-ski-slopes  key words and relative weights are:
#
# brantling 0.712
# diane 0.219
# roffe 0.174
# choclate 0.116
# edelwiess 0.116
#
#  mount-snow  key words and relative weights are:
#
# mount 0.52
# ripcord 0.428
# carinthia 0.242
# sunbrook 0.227
# stratton 0.179
#
#  greek-peak  key words and relative weights are:
#
# greek 0.907
# cny 0.114
# toggenburg 0.111
# labrador 0.069
# alpha 0.069
#
#  willard-mountain  key words and relative weights are:
#
# willard 0.806
# moreover 0.187
# nicley 0.152
# sidestep 0.134
# colonel 0.134
#
#  buck-hill  key words and relative weights are:
#
# buck 0.424
# afton 0.355
# metro 0.269
# buckhill 0.218
# earring 0.166
#
#  sunrise-park-resort  key words and relative weights are:
#
# sunrise 0.802
# cyclone 0.322
# apache 0.207
# arizona 0.19
# snowbowl 0.161
#
#  gunstock  key words and relative weights are:
#
# gunstock 0.743
# pistol 0.235
# panorama 0.187
# flintlock 0.117
# bliss 0.093
#
#  labrador-mt  key words and relative weights are:
#
# labrador 0.615
# cushioned 0.271
# songworst 0.271
# tog 0.238
# psia 0.166
#  ski-beech-mountain-resort  key words and relative weights are:
#
# beech 0.929
# sugar 0.122
# nc 0.101
# appalachian 0.066
# blower 0.054
#
#  mt-bachelor  key words and relative weights are:
#
# bachelor 0.825
# bend 0.192
# marten 0.156
# outback 0.134
# nw 0.104
#
#  welch-village  key words and relative weights are:
#
# welch 0.862
# afton 0.248
# grease 0.137
# twin 0.131
# stain 0.088
#
#  marquette-mountain  key words and relative weights are:
#
# marquette 0.762
# mm 0.193
# wandered 0.18
# nsp 0.102
# clift 0.09
#
#  afton-alps  key words and relative weights are:
#
# afton 0.939
# welch 0.145
# twin 0.094
# alp 0.086
# chalet 0.064
#
#  christmas-mountain  key words and relative weights are:
#
# existent 0.331
# snarkly 0.222
# tiny 0.216
# non 0.204
# dell 0.168
#
#  ragged-mountain-resort  key words and relative weights are:
#
# ragged 0.924
# spear 0.134
# barnyard 0.096
# ravine 0.091
# nh 0.074
#
#  magic-mountain-ski-area  key words and relative weights are:
#
# pomerelle 0.725
# magic 0.267
# twin 0.205
# majic 0.197
# additon 0.15
#
#  whitetail-resort  key words and relative weights are:
#
# whitetail 0.894
# dc 0.169
# liberty 0.128
# baltimore 0.05
# roundtop 0.05
#
#  shawnee-mountain-ski-area  key words and relative weights are:
#
# shawnee 0.863
# camelback 0.103
# tubing 0.075
# jesse 0.071
# seperately 0.071
#
#  ski-mystic-at-deer-mountain  key words and relative weights are:
#
# mystic 0.468
# deer 0.394
# terry 0.323
# virtual 0.146
# brianhead 0.146
#
#  swiss-valley  key words and relative weights are:
#
# swiss 0.738
# indiana 0.2
# roy 0.187
# mi 0.156
# bittersweet 0.147
#
#  toggenburg-mountain  key words and relative weights are:
#
# tog 0.739
# toggenburg 0.339
# lab 0.268
# song 0.224
# stared 0.134
#
#  eldora-mountain-resort  key words and relative weights are:
#
# eldora 0.897
# boulder 0.217
# nederland 0.15
# salto 0.067
# windy 0.066
#
#  west-mountain  key words and relative weights are:
#
# triple 0.196
# centerpost 0.15
# eveeywhere 0.15
# gnarwall 0.15
# ingred 0.15
#
#  wachusett-mountain-ski-area  key words and relative weights are:
#
# wachusett 0.728
# wachusetts 0.174
# waffle 0.125
# hitchcock 0.113
# walton 0.113
#
#  boreal  key words and relative weights are:
#
# boreal 0.919
# filed 0.094
# basement 0.077
# replacement 0.074
# board 0.073
#
#  alpine-valley  key words and relative weights are:
#
# ohio 0.275
# profect 0.241
# ungrounded 0.241
# alpine 0.216
# hometown 0.174
#
#  wilmot-mountain  key words and relative weights are:
#
# wilmot 0.835
# wilmont 0.152
# profoundly 0.11
# wisconsin 0.096
# alpine 0.084
#
#  arizona-snowbowl  key words and relative weights are:
#
# snowbowl 0.799
# arizona 0.31
# phoenix 0.188
# az 0.174
# flagstaff 0.173
#
#  stevens-pass-resort  key words and relative weights are:
#
# stevens 0.891
# crystal 0.133
# steven 0.126
# seattle 0.108
# lyon 0.067
#
#  wolf-ridge-ski-resort  key words and relative weights are:
#
# wolf 0.581
# laurel 0.225
# nc 0.139
# ridge 0.123
# beech 0.121
#
#  grand-geneva  key words and relative weights are:
#
# geneva 0.661
# grand 0.272
# wilmot 0.228
# coin 0.166
# allegedly 0.144
#
#  kissing-bridge  key words and relative weights are:
#
# kb 0.772
# holliday 0.521
# kissing 0.203
# bridge 0.116
# convince 0.067
#
#  hidden-valley-ski-area  key words and relative weights are:
#
# louis 0.427
# stl 0.265
# scion 0.199
# missouri 0.19
# hidden 0.163
#
#  timberline-four-seasons  key words and relative weights are:
#
# timberline 0.745
# salamander 0.258
# canaan 0.209
# snowshoe 0.133
# thunderstruck 0.117
#
#  hunter-mountain  key words and relative weights are:
#
# hunter 0.899
# kaatskill 0.144
# nyc 0.1
# clair 0.088
# flyer 0.085
#
#  liberty  key words and relative weights are:
#
# liberty 0.871
# eastwind 0.137
# stratum 0.137
# doodle 0.127
# whitetail 0.126
#
#  cooper-spur  key words and relative weights are:
#
# cooper 0.626
# spur 0.613
# unclear 0.141
# plexiglas 0.108
# shoers 0.108
#
#  49-degrees-north  key words and relative weights are:
#
# spokane 0.403
# schweitzer 0.337
# smelt 0.161
# boomtown 0.15
# chewelah 0.15
#
#  mountain-high  key words and relative weights are:
#
# mh 0.227
# la 0.189
# socal 0.162
# bear 0.153
# mat 0.151
#
#  snow-creek  key words and relative weights are:
#
# kc 0.444
# kansa 0.221
# missouri 0.18
# creek 0.169
# snowcreek 0.168
#
#  soda-springs  key words and relative weights are:
#
# tube 0.455
# soda 0.424
# boreal 0.175
# tubing 0.147
# belittling 0.122
#
#  cannonsburg  key words and relative weights are:
#
# cannonsburg 0.871
# thier 0.131
# tripple 0.128
# pando 0.127
# bittersweet 0.122
#
#  the-summit-at-snoqualmie  key words and relative weights are:
#
# alpental 0.536
# snoqualmie 0.422
# seattle 0.259
# summit 0.252
# stevens 0.176
#
#  bradford-ski-area  key words and relative weights are:
#
# bradford 0.912
# dough 0.149
# fried 0.127
# bnought 0.104
# gasoline 0.091
#
#  spring-mountain-ski-area  key words and relative weights are:
#
# spring 0.244
# philadelphia 0.156
# tubing 0.151
# canopy 0.148
# poconos 0.124
#
#  camelback-mountain-resort  key words and relative weights are:
#
# camelback 0.873
# cb 0.187
# poconos 0.069
# chateau 0.067
# misinformation 0.066
#
#  big-bear  key words and relative weights are:
#
# bear 0.562
# woodloch 0.282
# skying 0.16
# allian 0.141
# enoughparking 0.141
#
#  winterplace-ski-resort  key words and relative weights are:
#
# winterplace 0.883
# youth 0.086
# blower 0.08
# beech 0.075
# wintergreen 0.072
#
#  mount-la-crosse  key words and relative weights are:
#
# lacrosse 0.446
# crosse 0.235
# chalet 0.212
# merrillan 0.178
# midwest 0.169
#
#  villa-olivia  key words and relative weights are:
#
# bartlett 0.368
# villa 0.357
# olivia 0.343
# cage 0.246
# tow 0.187
#
#  ski-apache  key words and relative weights are:
#
# apache 0.872
# ruidoso 0.288
# gondola 0.109
# capitan 0.096
# texas 0.088
#
#  las-vegas-ski-and-snowboard-resort  key words and relative weights are:
#
# vega 0.736
# charleston 0.272
# lee 0.17
# la 0.156
# lvssr 0.155
#
#  hyland-ski-snowboard-area  key words and relative weights are:
#
# hyland 0.543
# crescent 0.482
# welch 0.275
# invalid 0.15
# afton 0.137
#
#  woodbury-ski-area  key words and relative weights are:
#
# woodbury 0.728
# wsa 0.203
# gald 0.135
# loooking 0.119
# groupon 0.119
#
#  sandia-peak  key words and relative weights are:
#
# sandia 0.602
# albuquerque 0.368
# tram 0.191
# diablo 0.18
# madera 0.18
#
#  sugar-mountain-resort  key words and relative weights are:
#
# sugar 0.804
# nc 0.211
# beech 0.143
# gunther 0.129
# carolina 0.111
#
#  ober-gatlinburg-ski-resort  key words and relative weights are:
#
# ober 0.737
# gatlinburg 0.484
# tram 0.117
# attraction 0.09
# fcc 0.086
#
#  mountain-creek-resort  key words and relative weights are:
#
# creek 0.466
# vernon 0.422
# jersey 0.244
# mc 0.236
# south 0.152
#
#  mount-brighton  key words and relative weights are:
#
# brighton 0.669
# holly 0.41
# mt 0.19
# knob 0.156
# detroit 0.154
#
#  campgaw-mountain  key words and relative weights are:
#
# campgaw 0.607
# craig 0.251
# gaw 0.166
# idiotic 0.126
# nag 0.126
#
#  whaleback-mountain  key words and relative weights are:
#
# mow 0.34
# tlc 0.322
# cute 0.262
# painting 0.225
# shrubbery 0.225
#
#  mt-crescent-ski-area  key words and relative weights are:
#
# crescent 0.659
# omaha 0.283
# sledder 0.202
# rescued 0.162
# iowa 0.157
#
#  holiday-mountain  key words and relative weights are:
#
# belary 0.247
# grommes 0.247
# homeade 0.247
# tralls 0.247
# twards 0.247

# %%
#  We normally ski at Belleayre.  Here we find the most frequently used words using TFIDF for Belleayre.
#  Here we see that Belleayre, Hunter and Windham are all mentioned.  These are the three ski centers in the
#  area which are all located next to each other.

#  Tomahawk and Superchief are two of the lifts which are new and of high quality.  Catskills is the name of 
#  mountain range where Belleayre is located.  And Discovery is the name of the lodge at the ski center.
from gensim.models.tfidfmodel import TfidfModel

#  Here we find the number of belleayre ski center in the list of ski centers
ski_areas_list = list(ski_areas.index)
df = ski_areas_list.index('belleayre')
print(ski_areas_list[df],"is position",df,"in the list of ski centers.")

#  here we pull out the weights for the correct ski center document

tfidf = TfidfModel(corpus_ski_areas)
tfidf_weights = tfidf[corpus_ski_areas[df]]

print('\n',ski_areas.index.values[df]," key words and relative weights are:\n")

# Sort the weights from highest to lowest: sorted_tfidf_weights
sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

# print out the top words and weights for belleayre ski center
# Also make a horizontal bar chart of the weights
bar_chart_data = {}
for term_id, weight in sorted_tfidf_weights[:10]:
    bar_chart_data[dictionary_ski_area.get(term_id)] = weight
    print(dictionary_ski_area.get(term_id), round(weight,3))
    
#  take the count data from above and create a bar chart

#  import the necessary library to make the bar chart
from matplotlib import pyplot as plt
plt.title("Top Words Appearing in the Reviews")
plt.xlabel('Key Words in Reviews')
plt.ylabel('TFIDF Weights')
keys = list(bar_chart_data.keys())
values = list(bar_chart_data.values())
plt.barh(keys,values)

print("\nThese are the top 10 words in Belleayre Reviews After Pre-Processing and TFIDF:\n")
# Out:
# belleayre is position 147 in the list of ski centers.
#
#  belleayre  key words and relative weights are:
#
# belleayre 0.835
# hunter 0.169
# tomahawk 0.163
# superchief 0.146
# windham 0.122
# catskills 0.103
# nyc 0.08
# consulting 0.073
# discovery 0.069
# boot 0.064
#
# These are the top 10 words in Belleayre Reviews After Pre-Processing and TFIDF:

# %%
#  Here we prepare a venn diagram between words in Belleayre Ski Center and Hunter Ski Center
#  These two ski centers are geographically next to each other and quite similar in characteristics.
#  Here the Venn Diagram seems quite balanced between the two ski centers

#Import libraries
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt
# %matplotlib inline


ski_areas_list = list(ski_areas.index)
df1 = ski_areas_list.index('belleayre')
df2 = ski_areas_list.index('hunter-mountain')
print(ski_areas_list[df1],"is position",df1,"in the list of ski centers.")
print(ski_areas_list[df2],"is position",df2,"in the list of ski centers.")

words_df1 = set()

for i in corpus_ski_areas[df1]:
        words_df1.add(i[0])

words_df2 = set()
for i in corpus_ski_areas[df2]:
        words_df2.add(i[0])

words_intersection = len(words_df1.intersection(words_df2))
words_in_df1_not_in_df2 = len(words_df1.difference(words_df2))
words_in_df2_not_in_df1= len(words_df2.difference(words_df1))
venn2(subsets = (words_in_df1_not_in_df2, words_in_df2_not_in_df1, words_intersection), set_labels = ('Belleayre Ski Center', 'Hunter Mountain'), set_colors=('r', 'g'), alpha = 0.5);
print("\nThere are",words_intersection,"in the intersection.")
print("There are",words_in_df1_not_in_df2,"Belleayre Ski Center")
print("There are",words_in_df2_not_in_df1,"Hunter Mountain")
print("There are",words_intersection+words_in_df1_not_in_df2+words_in_df2_not_in_df1,"total words")
# Out:
# belleayre is position 147 in the list of ski centers.
# hunter-mountain is position 262 in the list of ski centers.
#
# There are 815 in the intersection.
# There are 696 Belleayre Ski Center
# There are 983 Hunter Mountain
# There are 2494 total words

# %%
#  Here we compare two ski centers, Belleayre and Vail.  Vail is extremely popular and a huge world renowned 
#  resort.  Whereas Belleayre is for locals on the East Coast.
#  Here the Venn diagram show that there are many more words used to describe Vail and less unique 
#  words to describe Belleayre.

ski_areas_list = list(ski_areas.index)
df1 = ski_areas_list.index('belleayre')
df2 = ski_areas_list.index('vail')
print(ski_areas_list[df1],"is position",df1,"in the list of ski centers.")
print(ski_areas_list[df2],"is position",df2,"in the list of ski centers.")

words_df1 = set()

for i in corpus_ski_areas[df1]:
        words_df1.add(i[0])

words_df2 = set()
for i in corpus_ski_areas[df2]:
        words_df2.add(i[0])

words_intersection = len(words_df1.intersection(words_df2))
words_in_df1_not_in_df2 = len(words_df1.difference(words_df2))
words_in_df2_not_in_df1= len(words_df2.difference(words_df1))
venn2(subsets = (words_in_df1_not_in_df2, words_in_df2_not_in_df1, words_intersection), set_labels = ('Belleayre Ski Center', 'Vail'), set_colors=('r', 'g'), alpha = 0.5);
print("\nThere are",words_intersection,"in the intersection.")
print("There are",words_in_df1_not_in_df2,"Belleayre Ski Center")
print("There are",words_in_df2_not_in_df1,"Vail")
print("There are",words_intersection+words_in_df1_not_in_df2+words_in_df2_not_in_df1,"total words")
# Out:
# belleayre is position 147 in the list of ski centers.
# vail is position 112 in the list of ski centers.
#
# There are 959 in the intersection.
# There are 552 Belleayre Ski Center
# There are 1733 Vail
# There are 3244 total words
