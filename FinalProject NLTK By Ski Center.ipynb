# %%
# NLP Processing
# Processing by number of stars in the review
import pandas as pd
reviews = pd.read_csv ('OnTheSnow_SkiAreaReviews.csv')
reviews.columns = ['placeholder','state','ski_area','reviewer_name','review_date',
                        'review_stars','review_text']

ski_areas = reviews.groupby(['ski_area'])['ski_area'].count().sort_values(ascending=False)
#ski_areas.columns = ['ski_area']

# %%
ski_areas_stars = reviews.groupby(['ski_area','review_stars'])['review_stars'].mean().sort_values(ascending=False)

# %%
#ski_areas.iloc[:,1].sort_values()
print(ski_areas.head(10))
print(ski_areas_stars.head(10))
# Out:
# ski_area
# ski-brule                   1315
# killington-resort            204
# vail                         203
# winter-park-resort           191
# blue-mountain-ski-area       189
# breckenridge                 188
# ski-apache                   172
# heavenly-mountain-resort     157
# wolf-creek-ski-area          155
# steamboat                    150
# Name: ski_area, dtype: int64
# ski_area                     review_stars
# woods-valley-ski-area        5               5.0
# royal-mountain-ski-area      5               5.0
# perfect-north-slopes         5               5.0
# canaan-valley-resort         5               5.0
# pico-mountain-at-killington  5               5.0
# campgaw-mountain             5               5.0
# pine-knob-ski-resort         5               5.0
# pine-mountain                5               5.0
# camelback-mountain-resort    5               5.0
# plattekill-mountain          5               5.0
# Name: review_stars, dtype: float64

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import numpy as np



# Instantiate the WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

def get_clean_review(df):
    clean_review = []
    for index, row in df.iterrows():
        review_str = str(row['review_text'])
        # split the string into a list of words
        tokens = word_tokenize(review_str)
        lower_tokens = [t.lower() for t in tokens]

        # removes anything not alpha characters such as punctuation and numbers
        alpha_only = [t for t in lower_tokens if t.isalpha()]

        # removes the stop words from the text
        no_stops = [t for t in alpha_only if t not in stopwords.words('english')]

        # Lemmatize all tokens into a new list: lemmatized
        lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]

        # make a list of lists
        for w in lemmatized:
            clean_review.append(w)
        
    return clean_review

reviews_ski_area = []

for sa in ski_areas.index:
    print(sa)
    reviews_to_pass= reviews[reviews['ski_area']==sa]
    print(len(reviews_to_pass))
    reviews_ski_area.append( get_clean_review(reviews_to_pass))
# Out:
# ski-brule
# 1315
# killington-resort
# 204
# vail
# 203
# winter-park-resort
# 191
# blue-mountain-ski-area
# 189
# breckenridge
# 188
# ski-apache
# 172
# heavenly-mountain-resort
# 157
# wolf-creek-ski-area
# 155
# steamboat
# 150
# mountain-creek-resort
# 148
# camelback-mountain-resort
# 146
# snowshoe-mountain-resort
# 146
# mammoth-mountain-ski-area
# 142
# keystone
# 141
# alta-ski-area
# 140
# taos-ski-valley
# 138
# arapahoe-basin-ski-area
# 138
# copper-mountain-resort
# 138
# big-sky-resort
# 136
# mount-snow
# 135
# park-city-mountain-resort
# 135
# sno-mountain
# 134
# snowbird
# 134
# jay-peak
# 133
# okemo-mountain-resort
# 132
# sugar-mountain-resort
# 129
# sunrise-park-resort
# 121
# indianhead-mountain
# 115
# telluride
# 114
# squaw-valley-usa
# 113
# hunter-mountain
# 113
# stratton-mountain
# 111
# granite-peak-ski-area
# 111
# angel-fire-resort
# 111
# elk-mountain-ski-resort
# 108
# arizona-snowbowl
# 107
# kirkwood
# 107
# loveland
# 107
# beaver-creek
# 106
# stowe-mountain-resort
# 106
# jackson-hole
# 103
# northstar-california
# 102
# stevens-pass-resort
# 102
# mt-bachelor
# 101
# mt-hood-meadows
# 101
# deer-valley-resort
# 100
# ski-santa-fe
# 100
# crystal-mountain-wa
# 98
# durango-mountain-resort
# 97
# devils-head
# 95
# sunday-river
# 94
# snowbasin
# 94
# mt-baker
# 92
# sugarbush
# 90
# crested-butte-mountain-resort
# 89
# belleayre
# 89
# powder-mountain
# 88
# red-river
# 88
# loon-mountain
# 86
# gore-mountain
# 86
# lutsen-mountains
# 85
# eldora-mountain-resort
# 84
# bretton-woods
# 82
# smugglers-notch-resort
# 82
# whitefish-mountain-resort
# 82
# donner-ski-ranch
# 82
# ski-beech-mountain-resort
# 82
# solitude-mountain-resort
# 82
# wachusett-mountain-ski-area
# 81
# whiteface-mountain-resort
# 81
# jiminy-peak
# 80
# silver-mountain
# 80
# mountain-high
# 80
# mt-baldy
# 77
# cataloochee-ski-area
# 76
# mount-sunapee
# 75
# wisp
# 74
# alpine-valley-resort
# 74
# holiday-valley
# 73
# brighton-resort
# 73
# mad-river-mountain
# 72
# monarch-mountain
# 71
# schweitzer
# 71
# brian-head-resort
# 70
# lookout-pass-ski-area
# 70
# wintergreen-resort
# 69
# perfect-north-slopes
# 69
# bear-creek-mountain-resort
# 69
# cannonsburg
# 68
# liberty
# 68
# dodge-ridge
# 68
# whitetail-resort
# 68
# sun-valley
# 65
# grand-targhee-resort
# 64
# cascade-mountain
# 64
# ski-butternut
# 64
# ski-china-peak
# 64
# shanty-creek
# 63
# spring-mountain-ski-area
# 63
# timberline-four-seasons
# 62
# peekn-peak
# 62
# aspen-snowmass
# 62
# windham-mountain
# 61
# snow-valley
# 61
# snow-summit
# 60
# 49-degrees-north
# 60
# cannon-mountain
# 60
# catamount-ski-ride-area
# 60
# big-powderhorn-mountain
# 60
# bristol-mountain
# 59
# ragged-mountain-resort
# 59
# sierra-at-tahoe
# 59
# silverton-mountain
# 59
# bogus-basin
# 58
# winterplace-ski-resort
# 58
# bear-valley
# 57
# white-pass
# 57
# greek-peak
# 57
# sipapu-ski-and-summer-resort
# 57
# caberfae-peaks-ski-golf-resort
# 56
# pine-mountain
# 56
# roundtop-mountain-resort
# 55
# nubs-nob-ski-area
# 55
# attitash
# 55
# wilmot-mountain
# 55
# mount-peter-ski-area
# 55
# tamarack-resort
# 55
# las-vegas-ski-and-snowboard-resort
# 54
# waterville-valley
# 54
# whitecap-mountain
# 54
# alpental
# 54
# sugarloaf
# 54
# jack-frost
# 53
# the-summit-at-snoqualmie
# 53
# bear-mountain
# 52
# willamette-pass
# 52
# tahoe-donner
# 52
# blue-knob
# 51
# mount-bohemia
# 50
# pats-peak
# 50
# boyne-mountain-resort
# 50
# afton-alps
# 49
# bittersweet-ski-area
# 49
# mt-rose-ski-tahoe
# 49
# appalachian-ski-mtn
# 48
# boreal
# 48
# sugar-bowl-resort
# 48
# bolton-valley
# 47
# crotched-mountain
# 46
# massanutten
# 46
# ober-gatlinburg-ski-resort
# 46
# mohawk-mountain
# 46
# boyne-highlands
# 45
# boston-mills
# 45
# shawnee-mountain-ski-area
# 45
# crystal-mountain
# 44
# big-boulder
# 43
# red-lodge-mountain
# 43
# alyeska-resort
# 43
# bridger-bowl
# 43
# mission-ridge
# 42
# timberline-lodge
# 42
# mt-hood-ski-bowl
# 42
# chestnut-mountain-resort
# 41
# snowy-range-ski-recreation-area
# 41
# gunstock
# 41
# paoli-peaks
# 40
# spirit-mountain
# 40
# pico-mountain-at-killington
# 39
# brandywine
# 39
# welch-village
# 39
# ski-sundown
# 39
# magic-mountain
# 38
# mount-southington-ski-area
# 38
# ski-granby-ranch
# 38
# plattekill-mountain
# 38
# canaan-valley-resort
# 37
# sundance
# 37
# wildcat-mountain
# 37
# mount-brighton
# 37
# pomerelle-mountain-resort
# 36
# bromley-mountain
# 36
# wolf-ridge-ski-resort
# 36
# sunlight-mountain-resort
# 35
# west-mountain
# 35
# powderhorn
# 35
# berkshire-east
# 35
# big-bear
# 35
# tyrol-basin
# 35
# mad-river-glen
# 34
# buck-hill
# 34
# pebble-creek-ski-area
# 34
# pajarito-mountain-ski-area
# 34
# hoodoo-ski-area
# 33
# sandia-peak
# 33
# brundage-mountain-resort
# 33
# burke-mountain
# 33
# june-mountain
# 33
# hidden-valley-ski-area
# 33
# ski-cooper
# 32
# sunburst
# 32
# mount-holly
# 32
# campgaw-mountain
# 32
# discovery-ski-area
# 32
# diamond-peak
# 32
# mount-shasta-board-ski-park
# 32
# villa-olivia
# 31
# cranmore-mountain-resort
# 31
# bryce-resort
# 31
# wild-mountain-ski-snowboard-area
# 31
# lost-trail-powder-mtn
# 31
# great-divide
# 31
# snow-creek
# 30
# shawnee-peak
# 30
# timber-ridge
# 30
# montana-snowbowl
# 29
# sundown-mountain
# 29
# snow-trails
# 29
# mt-crescent-ski-area
# 28
# alpine-valley
# 28
# nordic-mountain
# 27
# swiss-valley
# 27
# hyland-ski-snowboard-area
# 27
# kissing-bridge
# 27
# bluewood
# 26
# marquette-mountain
# 26
# blackjack-ski-resort
# 26
# titus-mountain
# 26
# badger-pass
# 25
# mount-ashland
# 25
# terry-peak-ski-area
# 25
# soda-springs
# 25
# christmas-mountain
# 25
# eagle-point
# 25
# beaver-mountain
# 25
# blacktail-mountain-ski-area
# 24
# norway-mountain
# 24
# mount-la-crosse
# 23
# trollhaugen
# 23
# anthony-lakes-mountain-resort
# 22
# mt-abram-ski-resort
# 22
# woodbury-ski-area
# 22
# grand-geneva
# 21
# labrador-mt
# 21
# black-mountain
# 21
# ski-sawmill
# 21
# christie-mountain
# 21
# brantling-ski-slopes
# 21
# ski-snowstar-winter-sports-park
# 21
# andes-tower-hills-ski-area
# 20
# swain
# 20
# tussey-mountain
# 20
# magic-mountain-ski-area
# 20
# mccauley-mountain-ski-center
# 20
# hogadon
# 19
# toggenburg-mountain
# 19
# blandford-ski-area
# 19
# eagle-rock
# 19
# eaglecrest-ski-area
# 19
# cooper-spur
# 18
# soldier-mountain-ski-area
# 18
# dry-hill-ski-area
# 18
# holimont-ski-area
# 18
# wolf-creek
# 18
# suicide-six
# 18
# showdown-ski-area
# 17
# kelly-canyon-ski-area
# 17
# king-pine
# 17
# giants-ridge-resort
# 17
# woods-valley-ski-area
# 16
# royal-mountain-ski-area
# 16
# ski-mystic-at-deer-mountain
# 16
# bousquet-ski-area
# 16
# blue-hills-ski-area
# 16
# snow-ridge
# 15
# pine-knob-ski-resort
# 15
# song-mountain
# 15
# snow-king-resort
# 15
# mount-kato-ski-area
# 15
# new-hermon-mountain
# 14
# willard-mountain
# 14
# mount-holiday-ski-area
# 14
# bradford-ski-area
# 14
# bruce-mound
# 14
# big-squaw-mountain-ski-resort
# 13
# otis-ridge-ski-area
# 13
# holiday-mountain
# 13
# powder-ridge-ski-area
# 13
# coffee-mill-ski-snowboard-resort
# 13
# whaleback-mountain
# 12

# %%
from gensim.corpora.dictionary import Dictionary

# Create a Dictionary from the articles: dictionary
dictionary_ski_area = Dictionary(reviews_ski_area)

# Create a MmCorpus: corpus
corpus_ski_areas = [dictionary_ski_area.doc2bow(r) for r in reviews_ski_area]

# %%
from collections import defaultdict
import itertools

count =1 

#print("Here are the lengths of the documents in the corpus")
#for doc in corpus_ski_areas:
#    print(len(doc))

for doc in  corpus_ski_areas:
    print("Here is ski area:", count)
    count +=1
    # Sort the doc for frequency: bow_doc
    bow_doc = sorted(doc, key=lambda w: w[1], reverse=True)

    # Print the top 5 words of the document alongside the count
    for word_id, word_count in bow_doc[:5]:
        print(dictionary_ski_area.get(word_id), word_count)

    # Create the defaultdict: total_word_count
    total_word_count = defaultdict(int)
    for word_id, word_count in itertools.chain.from_iterable(corpus_ski_areas):
        total_word_count[word_id] += word_count
# Out:
# Here is ski area: 1
# great 820
# ski 757
# brule 524
# family 442
# friendly 390
# Here is ski area: 2
# killington 300
# mountain 213
# ski 172
# great 152
# trail 142
# Here is ski area: 3
# vail 416
# day 205
# ski 200
# get 158
# back 152
# Here is ski area: 4
# park 211
# ski 197
# winter 185
# mountain 172
# lift 165
# Here is ski area: 5
# mountain 268
# blue 256
# trail 158
# lift 156
# ski 136
# Here is ski area: 6
# ski 170
# great 169
# peak 168
# mountain 160
# breck 150
# Here is ski area: 7
# ski 286
# snow 174
# apache 165
# lift 164
# mountain 139
# Here is ski area: 8
# heavenly 206
# mountain 149
# lift 139
# ski 126
# get 115
# Here is ski area: 9
# wolf 206
# creek 193
# snow 167
# ski 130
# lift 128
# Here is ski area: 10
# steamboat 194
# mountain 122
# ski 108
# skiing 104
# great 100
# Here is ski area: 11
# mountain 237
# creek 155
# lift 137
# get 125
# ski 109
# Here is ski area: 12
# camelback 166
# mountain 164
# lift 156
# line 134
# trail 125
# Here is ski area: 13
# snowshoe 239
# resort 158
# lift 157
# ski 145
# snow 139
# Here is ski area: 14
# mammoth 234
# mountain 185
# great 104
# snow 104
# ski 93
# Here is ski area: 15
# keystone 236
# run 145
# resort 115
# ski 112
# great 110
# Here is ski area: 16
# alta 298
# ski 144
# day 134
# snow 114
# skiing 106
# Here is ski area: 17
# tao 265
# ski 214
# mountain 117
# great 110
# snow 98
# Here is ski area: 18
# mountain 108
# great 101
# resort 99
# run 98
# ski 98
# Here is ski area: 19
# copper 208
# mountain 170
# lift 9
# mountain 9
# skiing 7
# day 5
# Here is ski area: 287
# great 15
# ski 15
# mountain 12
# otis 11
# beginner 10
# Here is ski area: 288
# place 16
# ski 13
# hill 11
# like 11
# go 9
# Here is ski area: 289
# great 10
# place 10
# good 8
# hill 6
# night 6
# Here is ski area: 290
# ski 13
# run 11
# coffee 8
# skiing 8
# good 7
# Here is ski area: 291
# trail 27
# need 19
# open 15
# could 12
# enough 8

# %%
from gensim.models.tfidfmodel import TfidfModel

tfidf = TfidfModel(corpus_ski_areas)

# Calculate the tfidf weights of doc: tfidf_weights
counter = 0
for doc in corpus_ski_areas:
    tfidf_weights = tfidf[doc]
    
    print('\n',ski_areas.index.values[counter]," key words are:")
    counter +=1
    
    # Sort the weights from highest to lowest: sorted_tfidf_weights
    sorted_tfidf_weights = sorted(tfidf_weights, key=lambda w: w[1], reverse=True)

    # Print the top 5 weighted words
    for term_id, weight in sorted_tfidf_weights[:5]:
        print(dictionary_ski_area.get(term_id), round(weight,3))
# Out:
#  ski-brule  key words are:
# brule 0.963
# homestead 0.204
# bbq 0.07
# skiwee 0.031
# carload 0.027
#
#  killington-resort  key words are:
# killington 0.854
# pico 0.193
# snowshed 0.103
# powdr 0.091
# gondola 0.086
#
#  vail  key words are:
# vail 0.797
# bowl 0.206
# lionshead 0.195
# basin 0.13
# sky 0.118
#
#  winter-park-resort  key words are:
# jane 0.574
# wp 0.545
# mary 0.327
# mj 0.181
# parsenn 0.127
#
#  blue-mountain-ski-area  key words are:
# pa 0.353
# blue 0.268
# burma 0.235
# poconos 0.173
# razor 0.142
#
#  breckenridge  key words are:
# breck 0.661
# breckenridge 0.492
# imperial 0.26
# peak 0.178
# town 0.098
#
#  ski-apache  key words are:
# apache 0.872
# ruidoso 0.288
# gondola 0.109
# capitan 0.096
# texas 0.088
#
#  heavenly-mountain-resort  key words are:
# heavenly 0.792
# nevada 0.252
# gondola 0.205
# tahoe 0.17
# casino 0.132
#
#  wolf-creek-ski-area  key words are:
# wolf 0.747
# creek 0.372
# pagosa 0.37
# alberta 0.233
# wc 0.108
#
#  steamboat  key words are:
# steamboat 0.935
# morningside 0.108
# town 0.061
# gondola 0.061
# colorado 0.053
#
#  mountain-creek-resort  key words are:
# creek 0.466
# vernon 0.422
# jersey 0.244
# mc 0.236
# south 0.152
#
#  camelback-mountain-resort  key words are:
# camelback 0.873
# cb 0.187
# poconos 0.069
# chateau 0.067
# misinformation 0.066
#
#  snowshoe-mountain-resort  key words are:
# snowshoe 0.777
# territory 0.181
# silver 0.161
# silvercreek 0.146
# cupp 0.137
#
#  mammoth-mountain-ski-area  key words are:
# mammoth 0.928
# mccoy 0.067
# socal 0.063
# cornice 0.047
# california 0.046
#
#  keystone  key words are:
# keystone 0.864
# outback 0.235
# dercum 0.176
# gondola 0.098
# schoolmarm 0.097
#
#  alta-ski-area  key words are:
# alta 0.926
# collins 0.135
# snowbird 0.109
# supreme 0.082
# goldminer 0.077
#
#  taos-ski-valley  key words are:
# tao 0.935
# kachina 0.102
# tsv 0.094
# toas 0.063
# adobe 0.054
#
#  arapahoe-basin-ski-area  key words are:
# basin 0.407
# montezuma 0.352
# arapahoe 0.252
# pallavicini 0.189
# loveland 0.169
#
#  copper-mountain-resort  key words are:
# copper 0.885
# tucker 0.175
# village 0.121
# bee 0.092
# flyer 0.081
#
#  big-sky-resort  key words are:
# sky 0.507
# lone 0.44
# moonlight 0.369
# tram 0.208
# bozeman 0.175
#
#  mount-snow  key words are:
# mount 0.52
# ripcord 0.428
# carinthia 0.242
# sunbrook 0.227
# stratton 0.179
#
#  park-city-mountain-resort  key words are:
# pcmr 0.659
# city 0.326
# jupiter 0.247
# pc 0.18
# canyon 0.176
#
#  sno-mountain  key words are:
# sno 0.651
# montage 0.634
# lightning 0.117
# elk 0.092
# pa 0.085
#
#  snowbird  key words are:
# snowbird 0.707
# mineral 0.379
# alta 0.232
# tram 0.219
# peruvian 0.201
#
#  jay-peak  key words are:
# jay 0.928
# tram 0.138
# glade 0.086
# peak 0.071
# canadian 0.061
#
#  okemo-mountain-resort  key words are:
# okemo 0.874
# gore 0.269
# jackson 0.139
# ludlow 0.123
# killington 0.064
#
#  sugar-mountain-resort  key words are:
# sugar 0.804
# nc 0.211
# beech 0.143
# gunther 0.129
# carolina 0.111
#
#  sunrise-park-resort  key words are:
# sunrise 0.802
# cyclone 0.322
# apache 0.207
# arizona 0.19
# snowbowl 0.161
#
#  indianhead-mountain  key words are:
# indianhead 0.944
# suzanne 0.088
# midwest 0.076
# bikini 0.064
# powderhorn 0.063
#
#  telluride  key words are:
# telluride 0.867
# montrose 0.128
# palmyra 0.119
# town 0.107
# village 0.086
#
#  squaw-valley-usa  key words are:
# squaw 0.853
# tahoe 0.21
# chief 0.104
# kt 0.095
# shirley 0.095
#
#  hunter-mountain  key words are:
# hunter 0.899
# kaatskill 0.144
# nyc 0.1
# clair 0.088
# flyer 0.085
#
#  stratton-mountain  key words are:
# stratton 0.905
# gondola 0.125
# ursa 0.102
# ev 0.091
# village 0.06
#
#  granite-peak-ski-area  key words are:
# granite 0.736
# gp 0.321
# midwest 0.247
# peak 0.16
# wi 0.125
#
#  angel-fire-resort  key words are:
# angel 0.773
# af 0.329
# fire 0.315
# tao 0.151
# mexico 0.133
#
#  elk-mountain-ski-resort  key words are:
# elk 0.919
# pa 0.209
# sno 0.096
# camelback 0.081
# pennsylvania 0.08
#
#  arizona-snowbowl  key words are:
# snowbowl 0.799
# arizona 0.31
# phoenix 0.188
# az 0.174
# flagstaff 0.173
#
#  kirkwood  key words are:
# kirkwood 0.943
# tahoe 0.183
# heavenly 0.084
# sierra 0.052
# lake 0.044
#
#  loveland  key words are:
# loveland 0.948
# denver 0.102
# divide 0.062
# continental 0.057
# windy 0.048
#
#  beaver-creek  key words are:
# beaver 0.569
# creek 0.335
# grouse 0.283
# avon 0.279
# bc 0.255
#
#  stowe-mountain-resort  key words are:
# stowe 0.862
# spruce 0.205
# mansfield 0.182
# goat 0.119
# gondola 0.097
#
#  jackson-hole  key words are:
# jackson 0.597
# tram 0.36
# hole 0.195
# hobacks 0.193
# teton 0.168
#
#  northstar-california  key words are:
# northstar 0.904
# village 0.128
# backside 0.102
# squaw 0.101
# tahoe 0.088
#
#  stevens-pass-resort  key words are:
# stevens 0.891
# crystal 0.133
# steven 0.126
# seattle 0.108
# lyon 0.067
#
#  mt-bachelor  key words are:
# bachelor 0.825
# bend 0.192
# marten 0.156
# outback 0.134
# nw 0.104
#
#  mt-hood-meadows  key words are:
# meadow 0.672
# hood 0.441
# heather 0.254
# canyon 0.134
# portland 0.099
#
#  deer-valley-resort  key words are:
# deer 0.74
# dv 0.406
# valley 0.227
# canyon 0.115
# carpenter 0.077
#
#  ski-santa-fe  key words are:
# fe 0.684
# santa 0.638
# tao 0.132
# mexico 0.084
# millenium 0.072
#
#  crystal-mountain-wa  key words are:
# crystal 0.847
# snorting 0.136
# northway 0.132
# rainier 0.132
# washington 0.132
#
#  durango-mountain-resort  key words are:
# durango 0.726
# dmr 0.496
# purgatory 0.295
# purg 0.079
# tamarron 0.06
#
#  devils-head  key words are:
# devil 0.755
# cascade 0.167
# wisconsin 0.144
# granite 0.135
# head 0.132
#
#  sunday-river  key words are:
# jordan 0.468
# river 0.414
# barker 0.301
# oz 0.212
# aurora 0.208
#
#  snowbasin  key words are:
# snowbasin 0.827
# gondola 0.176
# strawberry 0.144
# ogden 0.134
# cottonwood 0.099
#
#  mt-baker  key words are:
# baker 0.941
# mt 0.065
# bellingham 0.064
# shuksan 0.064
# stevens 0.056
#
#  sugarbush  key words are:
# sugarbush 0.722
# ellen 0.369
# castlerock 0.291
# lincoln 0.226
# organgrinder 0.078
#
#  crested-butte-mountain-resort  key words are:
# cb 0.648
# butte 0.49
# crested 0.446
# town 0.118
# gunnison 0.09
#
#  belleayre  key words are:
# belleayre 0.835
# hunter 0.169
# tomahawk 0.163
# superchief 0.146
# windham 0.122
#
#  powder-mountain  key words are:
# snowbasin 0.291
# josh 0.287
# ogden 0.255
# powmow 0.253
# utah 0.199
#
#  red-river  key words are:
# red 0.64
# river 0.496
# rr 0.335
# tao 0.135
# town 0.134
#
#  loon-mountain  key words are:
# loon 0.89
# ripsaw 0.115
# gondola 0.101
# nh 0.093
# peak 0.082
#
#  gore-mountain  key words are:
# gore 0.879
# burnt 0.129
# saratoga 0.103
# gondola 0.09
# twister 0.077
#
#  lutsen-mountains  key words are:
# lutsen 0.858
# moose 0.287
# papa 0.149
# eagle 0.121
# caribou 0.106
#
#  eldora-mountain-resort  key words are:
# eldora 0.897
# boulder 0.217
# nederland 0.15
# salto 0.067
# windy 0.066
#
#  bretton-woods  key words are:
# bretton 0.82
# wood 0.237
# bw 0.193
# rosebrook 0.128
# glade 0.109
#
#  smugglers-notch-resort  key words are:
# smuggs 0.64
# madonna 0.457
# smuggler 0.251
# morse 0.228
# stowe 0.187
#
#  whitefish-mountain-resort  key words are:
# whitefish 0.815
# fog 0.232
# hellroaring 0.144
# kalispell 0.133
# foggy 0.116
#
#  donner-ski-ranch  key words are:
# donner 0.617
# dsr 0.612
# ranch 0.376
# asks 0.057
# bud 0.052
#
#  ski-beech-mountain-resort  key words are:
# beech 0.929
# sugar 0.122
# nc 0.101
# appalachian 0.066
# blower 0.054
#
#  solitude-mountain-resort  key words are:
# solitude 0.847
# honeycomb 0.319
# canyon 0.142
# brighton 0.104
# moonbeam 0.102
#
#  wachusett-mountain-ski-area  key words are:
# wachusett 0.728
# wachusetts 0.174
# waffle 0.125
# hitchcock 0.113
# walton 0.113
#
#  whiteface-mountain-resort  key words are:
# whiteface 0.859
# placid 0.326
# wilmington 0.108
# lake 0.081
# olympic 0.079
#
#  jiminy-peak  key words are:
# jiminy 0.754
# jp 0.241
# berkshire 0.154
# skiwee 0.119
# jason 0.113
#
#  silver-mountain  key words are:
# silver 0.791
# kellogg 0.211
# schweitzer 0.197
# gondola 0.189
# lookout 0.12
#
#  mountain-high  key words are:
# mh 0.227
# la 0.189
# socal 0.162
# bear 0.153
# mat 0.151
#
#  mt-baldy  key words are:
# baldy 0.925
# socal 0.164
# mt 0.079
# psych 0.054
# waterman 0.054
#
#  cataloochee-ski-area  key words are:
# cataloochee 0.826
# maggie 0.231
# nc 0.159
# atlanta 0.128
# louse 0.098
#
#  mount-sunapee  key words are:
# sunapee 0.856
# sunbowl 0.18
# boston 0.13
# signup 0.112
# mount 0.093
#
#  wisp  key words are:
# wisp 0.962
# dc 0.074
# coaster 0.058
# maryland 0.039
# ace 0.034
#
#  alpine-valley-resort  key words are:
# alpine 0.461
# chicago 0.339
# wisconsin 0.286
# devil 0.174
# valley 0.159
#
#  holiday-valley  key words are:
# hv 0.689
# ellicottville 0.27
# mound 0.145
# tannenbaum 0.139
# holiday 0.131
#
#  brighton-resort  key words are:
# brighton 0.94
# millicent 0.16
# milly 0.133
# slc 0.068
# snowbird 0.055
#
#  mad-river-mountain  key words are:
# ohio 0.484
# mad 0.434
# mrm 0.381
# river 0.326
# madriver 0.301
#
#  monarch-mountain  key words are:
# monarch 0.923
# mirkwood 0.18
# salida 0.166
# gunnison 0.073
# divide 0.05
#
#  schweitzer  key words are:
# schweitzer 0.878
# sandpoint 0.175
# selkirk 0.087
# pend 0.065
# detreed 0.057
#
#  brian-head-resort  key words are:
# brian 0.768
# bh 0.366
# brianhead 0.244
# navajo 0.171
# vega 0.124
#
#  lookout-pass-ski-area  key words are:
# lookout 0.929
# brundage 0.08
# hercules 0.073
# phil 0.059
# charley 0.049
#
#  wintergreen-resort  key words are:
# wintergreen 0.919
# illness 0.103
# virginia 0.065
# winery 0.062
# snowshoe 0.057
#
#  perfect-north-slopes  key words are:
# pns 0.722
# indiana 0.176
# lawrenceburg 0.128
# north 0.123
# clyde 0.102
#
#  bear-creek-mountain-resort  key words are:
# bear 0.515
# creek 0.34
# doe 0.237
# pa 0.188
# sasquatch 0.147
#
#  cannonsburg  key words are:
# cannonsburg 0.871
# thier 0.131
# tripple 0.128
# pando 0.127
# bittersweet 0.122
#
#  liberty  key words are:
# liberty 0.871
# eastwind 0.137
# stratum 0.137
# doodle 0.127
# whitetail 0.126
#
#  dodge-ridge  key words are:
# dodge 0.883
# tahoe 0.148
# ridge 0.113
# dodgeridge 0.091
# pinecrest 0.091
#
#  whitetail-resort  key words are:
# whitetail 0.894
# dc 0.169
# liberty 0.128
# baltimore 0.05
# roundtop 0.05
#
#  sun-valley  key words are:
# ketchum 0.463
# baldy 0.384
# sun 0.322
# valley 0.242
# hailey 0.143
#
#  grand-targhee-resort  key words are:
# targhee 0.826
# teton 0.283
# grand 0.205
# driggs 0.152
# gt 0.123
#
#  cascade-mountain  key words are:
# cascade 0.835
# midwest 0.158
# cindy 0.147
# wisconsin 0.128
# chicago 0.113
#
#  ski-butternut  key words are:
# butternut 0.883
# catamount 0.251
# nuthatch 0.059
# overrated 0.056
# jiminy 0.052
#
#  ski-china-peak  key words are:
# sierra 0.63
# china 0.475
# summit 0.212
# fresno 0.122
# mammoth 0.121
#
#  shanty-creek  key words are:
# schuss 0.636
# shanty 0.53
# bellaire 0.2
# michigan 0.181
# ivan 0.16
#
#  spring-mountain-ski-area  key words are:
# spring 0.244
# philadelphia 0.156
# tubing 0.151
# canopy 0.148
# poconos 0.124
#
#  timberline-four-seasons  key words are:
# timberline 0.745
# salamander 0.258
# canaan 0.209
# snowshoe 0.133
# thunderstruck 0.117
#
#  peekn-peak  key words are:
# peek 0.728
# pknpk 0.441
# n 0.278
# peak 0.139
# pk 0.135
#
#  aspen-snowmass  key words are:
# snowmass 0.69
# aspen 0.408
# buttermilk 0.297
# highland 0.264
# ajax 0.211
#
#  windham-mountain  key words are:
# windham 0.821
# hunter 0.353
# catskills 0.091
# nyc 0.082
# waffle 0.073
#
#  snow-valley  key words are:
# bear 0.326
# valley 0.308
# sunlight 0.185
# smoking 0.133
# cal 0.126
#
#  snow-summit  key words are:
# summit 0.373
# bear 0.332
# socal 0.177
# westridge 0.134
# california 0.128
#
#  49-degrees-north  key words are:
# spokane 0.403
# schweitzer 0.337
# smelt 0.161
# boomtown 0.15
# chewelah 0.15
#
#  cannon-mountain  key words are:
# cannon 0.815
# mittersill 0.288
# tram 0.143
# tuckerbrook 0.105
# zoomer 0.105
#
#  catamount-ski-ride-area  key words are:
# catamount 0.913
# butternut 0.165
# catapult 0.108
# barrington 0.09
# cultured 0.082
#
#  big-powderhorn-mountain  key words are:
# powderhorn 0.886
# caribou 0.201
# alpen 0.081
# midwest 0.076
# hideout 0.074
#
#  bristol-mountain  key words are:
# bristol 0.801
# swain 0.164
# rochester 0.136
# hunt 0.111
# rocket 0.095
#
#  ragged-mountain-resort  key words are:
# ragged 0.924
# spear 0.134
# barnyard 0.096
# ravine 0.091
# nh 0.074
#
#  sierra-at-tahoe  key words are:
# sierra 0.716
# tahoe 0.245
# pirate 0.156
# heavenly 0.14
# slipper 0.112
#
#  silverton-mountain  key words are:
# silverton 0.77
# guide 0.401
# unguided 0.18
# heli 0.124
# backcountry 0.078
#
#  bogus-basin  key words are:
# bogus 0.851
# boise 0.289
# basin 0.123
# insurance 0.103
# trampoline 0.057
#
#  winterplace-ski-resort  key words are:
# winterplace 0.883
# youth 0.086
# blower 0.08
# beech 0.075
# wintergreen 0.072
#
#  bear-valley  key words are:
# bear 0.543
# cub 0.257
# grizzly 0.213
# sierra 0.191
# valley 0.175
#
#  white-pass  key words are:
# white 0.526
# crystal 0.299
# scenary 0.151
# whitepass 0.149
# wp 0.143
#  greek-peak  key words are:
# greek 0.907
# cny 0.114
# toggenburg 0.111
# labrador 0.069
# alpha 0.069
#
#  sipapu-ski-and-summer-resort  key words are:
# sipapu 0.923
# tao 0.103
# fe 0.088
# santa 0.084
# teacher 0.069
#
#  caberfae-peaks-ski-golf-resort  key words are:
# caberfae 0.82
# crystal 0.264
# boyne 0.179
# michigan 0.167
# dub 0.129
#
#  pine-mountain  key words are:
# pine 0.696
# famers 0.148
# condo 0.109
# birthday 0.106
# brule 0.101
#
#  roundtop-mountain-resort  key words are:
# roundtop 0.838
# lafayette 0.192
# minuteman 0.169
# liberty 0.148
# ramrod 0.107
#
#  nubs-nob-ski-area  key words are:
# nub 0.862
# nob 0.317
# boyne 0.241
# pintail 0.13
# michigan 0.12
#
#  attitash  key words are:
# attitash 0.907
# bear 0.131
# bretton 0.106
# peak 0.09
# triple 0.075
#
#  wilmot-mountain  key words are:
# wilmot 0.835
# wilmont 0.152
# profoundly 0.11
# wisconsin 0.096
# alpine 0.084
#
#  mount-peter-ski-area  key words are:
# peter 0.811
# tuxedo 0.109
# mount 0.101
# hermon 0.096
# mt 0.089
#
#  tamarack-resort  key words are:
# tamarack 0.832
# brundage 0.332
# bogus 0.128
# idaho 0.121
# boise 0.114
#
#  las-vegas-ski-and-snowboard-resort  key words are:
# vega 0.736
# charleston 0.272
# lee 0.17
# la 0.156
# lvssr 0.155
#
#  waterville-valley  key words are:
# waterville 0.787
# wv 0.189
# bretten 0.128
# schwendi 0.128
# loon 0.106
#
#  whitecap-mountain  key words are:
# whitecap 0.888
# powderhorn 0.164
# indianhead 0.141
# cap 0.084
# southside 0.082
#
#  alpental  key words are:
# alpental 0.918
# snoqualmie 0.137
# nash 0.133
# bk 0.107
# alpy 0.095
#
#  sugarloaf  key words are:
# sugarloaf 0.849
# snowfield 0.207
# loaf 0.107
# skidder 0.104
# treeline 0.081
#
#  jack-frost  key words are:
# frost 0.715
# jack 0.548
# jf 0.21
# boulder 0.139
# camelback 0.126
#
#  the-summit-at-snoqualmie  key words are:
# alpental 0.536
# snoqualmie 0.422
# seattle 0.259
# summit 0.252
# stevens 0.176
#
#  bear-mountain  key words are:
# bear 0.683
# cal 0.159
# yur 0.142
# mammoth 0.137
# blackout 0.109
#
#  willamette-pass  key words are:
# willamette 0.879
# eugene 0.16
# wp 0.115
# oakridge 0.102
# oregon 0.099
#
#  tahoe-donner  key words are:
# donner 0.49
# fpr 0.221
# amd 0.178
# art 0.17
# spanish 0.158
#
#  blue-knob  key words are:
# knob 0.887
# pa 0.115
# stembogan 0.107
# studio 0.095
# extrovert 0.094
#
#  mount-bohemia  key words are:
# bohemia 0.866
# midwest 0.185
# yurt 0.132
# houghton 0.126
# mount 0.077
#
#  pats-peak  key words are:
# pat 0.705
# hurricane 0.399
# mesh 0.151
# peak 0.138
# metal 0.091
#
#  boyne-mountain-resort  key words are:
# boyne 0.818
# mclouth 0.183
# michigan 0.162
# hemlock 0.118
# museum 0.107
#
#  afton-alps  key words are:
# afton 0.939
# welch 0.145
# twin 0.094
# alp 0.086
# chalet 0.064
#
#  bittersweet-ski-area  key words are:
# bittersweet 0.796
# timber 0.184
# michigan 0.163
# cannonsburg 0.161
# timberridge 0.153
#
#  mt-rose-ski-tahoe  key words are:
# rose 0.815
# reno 0.372
# tahoe 0.142
# squaw 0.119
# chute 0.11
#
#  appalachian-ski-mtn  key words are:
# appalachian 0.619
# app 0.372
# sugar 0.197
# debit 0.177
# beech 0.152
#
#  boreal  key words are:
# boreal 0.919
# filed 0.094
# basement 0.077
# replacement 0.074
# board 0.073
#
#  sugar-bowl-resort  key words are:
# sugar 0.636
# bowl 0.26
# squaw 0.251
# lincoln 0.215
# tahoe 0.185
#
#  bolton-valley  key words are:
# bolton 0.906
# bv 0.11
# burlington 0.088
# valley 0.071
# wilderness 0.07
#
#  crotched-mountain  key words are:
# crotched 0.802
# cray 0.198
# boston 0.154
# wachusett 0.141
# choclates 0.099
#
#  massanutten  key words are:
# massanutten 0.829
# harrisonburg 0.231
# waterpark 0.124
# dc 0.087
# mouse 0.079
#
#  ober-gatlinburg-ski-resort  key words are:
# ober 0.737
# gatlinburg 0.484
# tram 0.117
# attraction 0.09
# fcc 0.086
#
#  mohawk-mountain  key words are:
# mohawk 0.868
# ct 0.202
# sundown 0.137
# liar 0.094
# voucher 0.078
#
#  boyne-highlands  key words are:
# boyne 0.534
# nub 0.448
# highland 0.442
# nob 0.295
# bh 0.209
#
#  boston-mills  key words are:
# bmbw 0.407
# brandywine 0.406
# mill 0.384
# tiger 0.283
# boston 0.238
#
#  shawnee-mountain-ski-area  key words are:
# shawnee 0.863
# camelback 0.103
# tubing 0.075
# jesse 0.071
# seperately 0.071
#
#  crystal-mountain  key words are:
# crystal 0.618
# michigan 0.348
# caberfae 0.237
# boyne 0.195
# fitness 0.141
#
#  big-boulder  key words are:
# boulder 0.602
# bb 0.519
# jf 0.205
# jfbb 0.16
# frost 0.151
#
#  red-lodge-mountain  key words are:
# red 0.489
# rlm 0.398
# cole 0.289
# bridger 0.206
# palisade 0.191
#
#  alyeska-resort  key words are:
# alyeska 0.801
# anchorage 0.303
# aly 0.202
# girdwood 0.177
# ak 0.145
#
#  bridger-bowl  key words are:
# bridger 0.86
# bozeman 0.263
# schlasman 0.141
# transceiver 0.099
# bowl 0.085
#
#  mission-ridge  key words are:
# mission 0.854
# wenatchee 0.262
# ridge 0.153
# bomber 0.142
# liberator 0.09
#
#  timberline-lodge  key words are:
# timberline 0.722
# hood 0.232
# skibowl 0.169
# oregon 0.151
# palmer 0.143
#
#  mt-hood-ski-bowl  key words are:
# hood 0.385
# skibowl 0.337
# bowl 0.33
# meadow 0.238
# outback 0.217
#
#  chestnut-mountain-resort  key words are:
# chestnut 0.82
# warpath 0.169
# mississippi 0.162
# midwest 0.14
# illinois 0.118
#
#  snowy-range-ski-recreation-area  key words are:
# snowy 0.63
# range 0.26
# centennial 0.177
# laramie 0.154
# definatly 0.117
#
#  gunstock  key words are:
# gunstock 0.743
# pistol 0.235
# panorama 0.187
# flintlock 0.117
# bliss 0.093
#
#  paoli-peaks  key words are:
# paoli 0.936
# indiana 0.115
# louisville 0.082
# snowshoe 0.062
# lick 0.062
#
#  spirit-mountain  key words are:
# spirit 0.827
# gandy 0.234
# moosehead 0.175
# lutsen 0.169
# duluth 0.153
#
#  pico-mountain-at-killington  key words are:
# pico 0.882
# killington 0.319
# activated 0.079
# representative 0.067
# ka 0.06
#
#  brandywine  key words are:
# brandywine 0.815
# mill 0.247
# ohio 0.22
# boston 0.171
# bmbw 0.1
#
#  welch-village  key words are:
# welch 0.862
# afton 0.248
# grease 0.137
# twin 0.131
# stain 0.088
#
#  ski-sundown  key words are:
# sundown 0.811
# ct 0.233
# mohawk 0.124
# gunbarrel 0.122
# lil 0.114
#
#  magic-mountain  key words are:
# magic 0.609
# vermont 0.237
# okemo 0.203
# bromley 0.166
# stratton 0.127
#
#  mount-southington-ski-area  key words are:
# southington 0.872
# ct 0.254
# jjt 0.099
# sundown 0.089
# hafe 0.087
#
#  ski-granby-ranch  key words are:
# sol 0.554
# granby 0.361
# solvista 0.361
# vista 0.343
# ranch 0.129
#
#  plattekill-mountain  key words are:
# plattekill 0.798
# catskills 0.263
# belleayre 0.137
# windham 0.121
# hunter 0.104
#
#  canaan-valley-resort  key words are:
# canaan 0.744
# timberline 0.224
# wv 0.188
# sanford 0.16
# davis 0.145
#
#  sundance  key words are:
# sundance 0.88
# nostalgic 0.121
# redford 0.12
# robert 0.091
# foundry 0.08
#
#  wildcat-mountain  key words are:
# wildcat 0.805
# polecat 0.192
# washington 0.128
# pinkham 0.115
# cheetah 0.101
#
#  mount-brighton  key words are:
# brighton 0.669
# holly 0.41
# mt 0.19
# knob 0.156
# detroit 0.154
#
#  pomerelle-mountain-resort  key words are:
# pomerelle 0.939
# idaho 0.114
# turnoff 0.065
# appprox 0.043
# bashful 0.043
#
#  bromley-mountain  key words are:
# bromley 0.938
# stratton 0.091
# stargazer 0.064
# vermont 0.062
# manchester 0.052
#
#  wolf-ridge-ski-resort  key words are:
# wolf 0.581
# laurel 0.225
# nc 0.139
# ridge 0.123
# beech 0.121
#
#  sunlight-mountain-resort  key words are:
# sunlight 0.915
# glenwood 0.148
# stole 0.093
# brettleberg 0.073
# erich 0.073
#
#  west-mountain  key words are:
# triple 0.196
# centerpost 0.15
# eveeywhere 0.15
# gnarwall 0.15
# ingred 0.15
#
#  powderhorn  key words are:
# powderhorn 0.847
# mesa 0.152
# evident 0.095
# inviting 0.088
# quintessential 0.087
#
#  berkshire-east  key words are:
# berkshire 0.834
# east 0.136
# jiminy 0.13
# chief 0.107
# england 0.094
#
#  big-bear  key words are:
# bear 0.562
# woodloch 0.282
# skying 0.16
# allian 0.141
# enoughparking 0.141
#
#  tyrol-basin  key words are:
# tyrol 0.912
# basin 0.161
# wisconsin 0.135
# cable 0.07
# accress 0.07
#
#  mad-river-glen  key words are:
# mrg 0.678
# glen 0.236
# mad 0.23
# antelope 0.219
# river 0.169
#
#  buck-hill  key words are:
# buck 0.424
# afton 0.355
# metro 0.269
# buckhill 0.218
# earring 0.166
#
#  pebble-creek-ski-area  key words are:
# pebble 0.937
# stacy 0.088
# creek 0.088
# inkom 0.073
# pocatello 0.073
#
#  pajarito-mountain-ski-area  key words are:
# pajarito 0.658
# fe 0.266
# alamo 0.261
# santa 0.253
# los 0.185
#
#  hoodoo-ski-area  key words are:
# hoodoo 0.865
# oregon 0.183
# willamette 0.144
# bachelor 0.112
# nìght 0.089
#
#  sandia-peak  key words are:
# sandia 0.602
# albuquerque 0.368
# tram 0.191
# diablo 0.18
# madera 0.18
#
#  brundage-mountain-resort  key words are:
# brundage 0.828
# idaho 0.215
# mccall 0.143
# ole 0.09
# boise 0.09
#
#  burke-mountain  key words are:
# burke 0.894
# initiated 0.11
# jay 0.088
# quiros 0.082
# willoughby 0.082
#
#  june-mountain  key words are:
# june 0.848
# mammoth 0.364
# interlaken 0.088
# andestination 0.059
# righteous 0.059
#
#  hidden-valley-ski-area  key words are:
# louis 0.427
# stl 0.265
# scion 0.199
# missouri 0.19
# hidden 0.163
#
#  ski-cooper  key words are:
# cooper 0.775
# leadville 0.288
# division 0.247
# veteran 0.147
# war 0.128
#
#  sunburst  key words are:
# sunburst 0.855
# moly 0.126
# tinny 0.126
# milwaukee 0.119
# psia 0.115
#
#  mount-holly  key words are:
# holly 0.82
# michigan 0.24
# mount 0.132
# se 0.122
# sheeshhh 0.119
#
#  campgaw-mountain  key words are:
# campgaw 0.607
# craig 0.251
# gaw 0.166
# idiotic 0.126
# nag 0.126
#
#  discovery-ski-area  key words are:
# discovery 0.713
# georgetown 0.39
# montana 0.196
# disco 0.168
# anaconda 0.133
#
#  diamond-peak  key words are:
# tahoe 0.367
# dp 0.253
# peak 0.213
# incline 0.196
# lake 0.168
#
#  mount-shasta-board-ski-park  key words are:
# shasta 0.907
# washboard 0.096
# scammer 0.084
# mt 0.082
# coyote 0.073
#
#  villa-olivia  key words are:
# bartlett 0.368
# villa 0.357
# olivia 0.343
# cage 0.246
# tow 0.187
#
#  cranmore-mountain-resort  key words are:
# cranmore 0.847
# arial 0.117
# bandit 0.117
# flipped 0.103
# disapointing 0.089
#
#  bryce-resort  key words are:
# bryce 0.918
# horst 0.118
# va 0.085
# virginia 0.084
# nc 0.067
#
#  wild-mountain-ski-snowboard-area  key words are:
# wild 0.765
# afton 0.299
# noticeably 0.175
# welch 0.112
# alp 0.111
#
#  lost-trail-powder-mtn  key words are:
# lost 0.404
# thoes 0.213
# montana 0.196
# missoula 0.172
# brutally 0.152
#
#  great-divide  key words are:
# divide 0.668
# rawhide 0.275
# helena 0.206
# belmont 0.166
# wild 0.108
#
#  snow-creek  key words are:
# kc 0.444
# kansa 0.221
# missouri 0.18
# creek 0.169
# snowcreek 0.168
#
#  shawnee-peak  key words are:
# shawnee 0.885
# conway 0.087
# structured 0.075
# joyless 0.075
# cosmetic 0.075
#
#  timber-ridge  key words are:
# bittersweet 0.521
# timber 0.39
# sw 0.347
# michigan 0.255
# mi 0.113
#
#  montana-snowbowl  key words are:
# snowbowl 0.604
# missoula 0.285
# pizza 0.142
# bowl 0.142
# selfies 0.141
#
#  sundown-mountain  key words are:
# sundown 0.744
# chestnut 0.458
# iowa 0.165
# arkansas 0.096
# handywork 0.096
#
#  snow-trails  key words are:
# ohio 0.515
# snowtrails 0.285
# cooling 0.228
# rimfire 0.186
# loft 0.163
#
#  mt-crescent-ski-area  key words are:
# crescent 0.659
# omaha 0.283
# sledder 0.202
# rescued 0.162
# iowa 0.157
#
#  alpine-valley  key words are:
# ohio 0.275
# profect 0.241
# ungrounded 0.241
# alpine 0.216
# hometown 0.174
#
#  nordic-mountain  key words are:
# nordic 0.572
# footer 0.316
# ahem 0.22
# atomsphere 0.22
# wisco 0.193
#
#  swiss-valley  key words are:
# swiss 0.738
# indiana 0.2
# roy 0.187
# mi 0.156
# bittersweet 0.147
#
#  hyland-ski-snowboard-area  key words are:
# hyland 0.543
# crescent 0.482
# welch 0.275
# invalid 0.15
# afton 0.137
#
#  kissing-bridge  key words are:
# kb 0.772
# holliday 0.521
# kissing 0.203
# bridge 0.116
# convince 0.067
#
#  bluewood  key words are:
# bluewood 0.914
# dayton 0.166
# huckleberry 0.094
# tucannon 0.094
# fin 0.068
#
#  marquette-mountain  key words are:
# marquette 0.762
# mm 0.193
# wandered 0.18
# nsp 0.102
# clift 0.09
#
#  blackjack-ski-resort  key words are:
# blackjack 0.754
# fantasticly 0.189
# tohoe 0.189
# mighty 0.129
# anyplace 0.112
#
#  titus-mountain  key words are:
# titus 0.887
# whiteface 0.265
# calabogie 0.11
# syrup 0.089
# canadian 0.076
#
#  badger-pass  key words are:
# yosemite 0.837
# badger 0.433
# snowshoing 0.095
# veteran 0.066
# northstar 0.065
#
#  mount-ashland  key words are:
# ashland 0.88
# bachelor 0.112
# benjamin 0.112
# drunken 0.09
# complainer 0.09
#
#  terry-peak-ski-area  key words are:
# terry 0.828
# afforable 0.233
# coziest 0.145
# rearing 0.145
# unavaible 0.145
#
#  soda-springs  key words are:
# tube 0.455
# soda 0.424
# boreal 0.175
# tubing 0.147
# belittling 0.122
#
#  christmas-mountain  key words are:
# existent 0.331
# snarkly 0.222
# tiny 0.216
# non 0.204
# estimated 0.168
#
#  eagle-point  key words are:
# eagle 0.608
# brianhead 0.293
# unit 0.282
# point 0.192
# bruh 0.155
#
#  beaver-mountain  key words are:
# beav 0.835
# beaver 0.338
# logan 0.138
# skithebeav 0.138
# mm 0.099
#
#  blacktail-mountain-ski-area  key words are:
# blacktail 0.807
# flathead 0.474
# fog 0.123
# whitefish 0.081
# exhange 0.059
#
#  norway-mountain  key words are:
# norway 0.583
# fried 0.161
# fish 0.152
# reopened 0.144
# clued 0.131
#
#  mount-la-crosse  key words are:
# lacrosse 0.446
# crosse 0.235
# chalet 0.212
# merrillan 0.178
# midwest 0.169
#
#  trollhaugen  key words are:
# trollhaugen 0.882
# troll 0.272
# skyefall 0.156
# hudson 0.125
# festival 0.085
#
#  anthony-lakes-mountain-resort  key words are:
# anthony 0.567
# oregon 0.171
# aspirin 0.165
# haines 0.165
# quarterpipe 0.165
#
#  mt-abram-ski-resort  key words are:
# abram 0.808
# abrahm 0.215
# abrams 0.142
# mt 0.115
# approachable 0.111
#
#  woodbury-ski-area  key words are:
# woodbury 0.728
# wsa 0.203
# gald 0.135
# loooking 0.119
# groupon 0.119
#
#  grand-geneva  key words are:
# geneva 0.661
# grand 0.272
# wilmot 0.228
# coin 0.166
# allegedly 0.144
#
#  labrador-mt  key words are:
# labrador 0.615
# cushioned 0.271
# songworst 0.271
# tog 0.238
# psia 0.166
#
#  black-mountain  key words are:
# passport 0.408
# hampshire 0.239
# dependent 0.169
# aging 0.155
# reselling 0.138
#
#  ski-sawmill  key words are:
# sawmill 0.927
# toboggan 0.081
# bunkhouse 0.081
# consequence 0.076
# expects 0.076
#
#  christie-mountain  key words are:
# christie 0.759
# diffiulty 0.155
# pressured 0.155
# traisl 0.155
# terain 0.114
#
#  brantling-ski-slopes  key words are:
# brantling 0.712
# diane 0.219
# roffe 0.174
# choclate 0.116
# edelwiess 0.116
#
#  ski-snowstar-winter-sports-park  key words are:
# snowstar 0.878
# wendy 0.194
# illinois 0.105
# chicago 0.081
# burbs 0.08
#
#  andes-tower-hills-ski-area  key words are:
# andes 0.884
# tower 0.136
# haiwian 0.112
# chalet 0.1
# te 0.098
#
#  swain  key words are:
# swain 0.906
# raving 0.143
# robinson 0.117
# favorable 0.082
# facebook 0.068
#
#  tussey-mountain  key words are:
# tussey 0.933
# snowtube 0.085
# fulfills 0.085
# laugh 0.081
# barreling 0.078
#
#  magic-mountain-ski-area  key words are:
# pomerelle 0.725
# magic 0.267
# twin 0.205
# majic 0.197
# additon 0.15
#
#  mccauley-mountain-ski-center  key words are:
# mccauley 0.869
# horible 0.132
# jeff 0.13
# tuning 0.121
# forge 0.116
#
#  hogadon  key words are:
# casper 0.791
# hogadon 0.395
# hogadons 0.225
# ratty 0.198
# replacing 0.113
#
#  toggenburg-mountain  key words are:
# tog 0.739
# toggenburg 0.339
# lab 0.268
# song 0.224
# stared 0.134
#
#  blandford-ski-area  key words are:
# blandford 0.533
# wonky 0.213
# stormed 0.213
# pico 0.166
# commend 0.166
#
#  eagle-rock  key words are:
# eagle 0.475
# seating 0.25
# frost 0.22
# dirt 0.209
# allocate 0.186
#
#  eaglecrest-ski-area  key words are:
# eaglecrest 0.793
# juneau 0.287
# alaska 0.198
# lindh 0.164
# elk 0.112
#
#  cooper-spur  key words are:
# cooper 0.626
# spur 0.613
# unclear 0.141
# plexiglas 0.108
# shoers 0.108
#
#  soldier-mountain-ski-area  key words are:
# soldier 0.81
# idaho 0.241
# soilder 0.141
# pop 0.134
# accommodates 0.124
#
#  dry-hill-ski-area  key words are:
# dry 0.551
# titus 0.352
# insrtucters 0.218
# givin 0.176
# isa 0.176
#
#  holimont-ski-area  key words are:
# holimont 0.865
# ellicottville 0.14
# burke 0.14
# motorized 0.123
# weekday 0.085
#
#  wolf-creek  key words are:
# snowbasin 0.503
# wolf 0.311
# exhillirating 0.205
# intermitently 0.205
# reponse 0.205
#
#  suicide-six  key words are:
# suicide 0.437
# woodstock 0.254
# lent 0.193
# skiway 0.193
# teago 0.193
#
#  showdown-ski-area  key words are:
# showdown 0.717
# everyweekend 0.179
# funn 0.157
# purest 0.144
# timely 0.144
#
#  kelly-canyon-ski-area  key words are:
# kelly 0.707
# kelleys 0.269
# rexburg 0.236
# canyon 0.157
# idaho 0.152
#
#  king-pine  key words are:
# kp 0.397
# pine 0.359
# king 0.351
# thirty 0.286
# purity 0.198
#
#  giants-ridge-resort  key words are:
# giant 0.686
# lutsen 0.308
# ridge 0.287
# reccomendation 0.186
# wynne 0.173
#
#  woods-valley-ski-area  key words are:
# glogging 0.323
# steered 0.283
# judging 0.221
# pie 0.205
# zone 0.198
#
#  royal-mountain-ski-area  key words are:
# royal 0.709
# laided 0.33
# moutian 0.266
# privately 0.202
# jim 0.196
#
#  ski-mystic-at-deer-mountain  key words are:
# mystic 0.468
# deer 0.394
# terry 0.323
# brianhead 0.146
# virtual 0.146
#
#  bousquet-ski-area  key words are:
# bosquet 0.521
# bousquet 0.35
# comer 0.263
# pittsfield 0.261
# bouquet 0.174
#
#  blue-hills-ski-area  key words are:
# yell 0.35
# bluehills 0.265
# monopolized 0.265
# boston 0.258
# certification 0.233
#
#  snow-ridge  key words are:
# tug 0.191
# utica 0.191
# titus 0.175
# whiteface 0.174
# pod 0.164
#
#  pine-knob-ski-resort  key words are:
# knob 0.309
# shaboom 0.308
# brighton 0.232
# vert 0.219
# pine 0.203
#
#  song-mountain  key words are:
# song 0.822
# syracuse 0.239
# sentimental 0.167
# defiantly 0.142
# deffanatlly 0.126
#
#  snow-king-resort  key words are:
# jackson 0.452
# king 0.445
# hole 0.271
# mounntain 0.21
# til 0.191
#
#  mount-kato-ski-area  key words are:
# kato 0.719
# sioux 0.217
# mn 0.197
# mankato 0.189
# bestt 0.144
#
#  new-hermon-mountain  key words are:
# hermon 0.451
# bangor 0.411
# camden 0.206
# parrallel 0.206
# trailblaze 0.206
#
#  willard-mountain  key words are:
# willard 0.806
# moreover 0.187
# nicley 0.152
# colonel 0.134
# sidestep 0.134
#
#  mount-holiday-ski-area  key words are:
# traverse 0.281
# policy 0.23
# realise 0.227
# grandeur 0.209
# zipline 0.195
#
#  bradford-ski-area  key words are:
# bradford 0.912
# dough 0.149
# fried 0.127
# bnought 0.104
# gasoline 0.091
#
#  bruce-mound  key words are:
# mound 0.422
# bruce 0.388
# adjoining 0.269
# declan 0.269
# bluff 0.203
#
#  big-squaw-mountain-ski-resort  key words are:
# greenville 0.505
# moosehead 0.294
# yosemite 0.294
# marriott 0.22
# b 0.18
#
#  otis-ridge-ski-area  key words are:
# otis 0.585
# wire 0.281
# coil 0.247
# brownish 0.141
# bulley 0.141
#
#  holiday-mountain  key words are:
# belary 0.247
# grommes 0.247
# homeade 0.247
# tralls 0.247
# twards 0.247
#
#  powder-ridge-ski-area  key words are:
# advenced 0.422
# bords 0.422
# mae 0.37
# throught 0.302
# stride 0.277
#
#  coffee-mill-ski-snowboard-resort  key words are:
# mill 0.355
# coffee 0.255
# cushioning 0.21
# hangar 0.21
# octangular 0.21
#
#  whaleback-mountain  key words are:
# mow 0.34
# tlc 0.322
# cute 0.262
# painting 0.225
# shrubbery 0.225
